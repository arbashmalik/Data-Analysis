# %% [markdown]
# # Loading helper libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import re
import ast
import patsy
import datetime
import math

from pathlib import Path
from patsy import dmatrices
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import permutation_importance
from sklearn.inspection import PartialDependenceDisplay
from sklearn.inspection import partial_dependence
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from plotnine import *
from stargazer import stargazer
from statsmodels.tools.eval_measures import mse,rmse
from collections import defaultdict
from sklearn.linear_model import Lasso
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import ElasticNet
from plotnine.data import mpg
from mizani.formatters import percent_format

# %%
path = Path(os.getcwd())
tech_prep = os.path.join(str(path), "utils")
sys.path.append(tech_prep)
from py_helper_functions import *

# %% [markdown]
# # Loading Dataset
#
# ### 1. main_df is the main dataset for my city, Lisbon.
# ### 2. amenities_cleaned_df is the dataset used for mapping amenities to my definitons

# %%
main_df = pd.read_csv('https://raw.githubusercontent.com/arbash-malik/DA3/main/Assignment%202/lisbon_listings.csv', delimiter=",",encoding="utf-8")
amenities_cleaned_df = pd.read_csv('https://raw.githubusercontent.com/arbash-malik/DA3/main/Assignment%202/unique_amenities_cleaned.csv', delimiter=",",encoding="utf-8")

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22605 entries, 0 to 22604
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            22605 non-null  int64
#  1   listing_url                                   22605 non-null  object
#  2   scrape_id                                     22605 non-null  int64
#  3   last_scraped                                  22605 non-null  object
#  4   source                                        22605 non-null  object
#  5   name                                          22605 non-null  object
#  6   description                                   22586 non-null  object
#  7   neighborhood_overview                         13429 non-null  object
#  8   picture_url                                   22605 non-null  object
#  9   host_id                                       22605 non-null  int64
#  10  host_url                                      22605 non-null  object
#  11  host_name                                     22604 non-null  object
#  12  host_since                                    22604 non-null  object
#  13  host_location                                 16801 non-null  object
#  14  host_about                                    12921 non-null  object
#  15  host_response_time                            20299 non-null  object
#  16  host_response_rate                            20299 non-null  object
#  17  host_acceptance_rate                          20912 non-null  object
#  18  host_is_superhost                             21976 non-null  object
#  19  host_thumbnail_url                            22604 non-null  object
#  20  host_picture_url                              22604 non-null  object
#  21  host_neighbourhood                            9439 non-null   object
#  22  host_listings_count                           22604 non-null  float64
#  23  host_total_listings_count                     22604 non-null  float64
#  24  host_verifications                            22604 non-null  object
#  25  host_has_profile_pic                          22604 non-null  object
#  26  host_identity_verified                        22604 non-null  object
#  27  neighbourhood                                 13429 non-null  object
#  28  neighbourhood_cleansed                        22605 non-null  object
#  29  neighbourhood_group_cleansed                  22605 non-null  object
#  30  latitude                                      22605 non-null  float64
#  31  longitude                                     22605 non-null  float64
#  32  property_type                                 22605 non-null  object
#  33  room_type                                     22605 non-null  object
#  34  accommodates                                  22605 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                22580 non-null  object
#  37  bedrooms                                      17472 non-null  float64
#  38  beds                                          22425 non-null  float64
#  39  amenities                                     22605 non-null  object
#  40  price                                         22605 non-null  object
#  41  minimum_nights                                22605 non-null  int64
#  42  maximum_nights                                22605 non-null  int64
#  43  minimum_minimum_nights                        22605 non-null  int64
#  44  maximum_minimum_nights                        22605 non-null  int64
#  45  minimum_maximum_nights                        22605 non-null  int64
#  46  maximum_maximum_nights                        22605 non-null  int64
#  47  minimum_nights_avg_ntm                        22605 non-null  float64
#  48  maximum_nights_avg_ntm                        22605 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              22605 non-null  object
#  51  availability_30                               22605 non-null  int64
#  52  availability_60                               22605 non-null  int64
#  53  availability_90                               22605 non-null  int64
#  54  availability_365                              22605 non-null  int64
#  55  calendar_last_scraped                         22605 non-null  object
#  56  number_of_reviews                             22605 non-null  int64
#  57  number_of_reviews_ltm                         22605 non-null  int64
#  58  number_of_reviews_l30d                        22605 non-null  int64
#  59  first_review                                  19919 non-null  object
#  60  last_review                                   19919 non-null  object
#  61  review_scores_rating                          19919 non-null  float64
#  62  review_scores_accuracy                        19887 non-null  float64
#  63  review_scores_cleanliness                     19887 non-null  float64
#  64  review_scores_checkin                         19887 non-null  float64
#  65  review_scores_communication                   19887 non-null  float64
#  66  review_scores_location                        19885 non-null  float64
#  67  review_scores_value                           19887 non-null  float64
#  68  license                                       21240 non-null  object
#  69  instant_bookable                              22605 non-null  object
#  70  calculated_host_listings_count                22605 non-null  int64
#  71  calculated_host_listings_count_entire_homes   22605 non-null  int64
#  72  calculated_host_listings_count_private_rooms  22605 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   22605 non-null  int64
#  74  reviews_per_month                             19919 non-null  float64
# dtypes: float64(18), int64(21), object(36)
# memory usage: 12.9+ MB

# %% [markdown]
# #### Since our client  will be operating small and mid-size apartments hosting 2-6 guests. It makes sense to filter out listings that are a room or a shared unit and only keep the ones that a customer can book entirely

# %%
main_df = main_df[main_df["property_type"].str.contains(r'^Entire', regex=True)] # fitlering for entire property types
main_df = main_df.loc[(main_df['accommodates'] >= 2) & (main_df['accommodates'] <= 6)] # fitlering for 2-6 accommodates

# %%
main_df.head().T
# Out:
#                                                                                               0  \
# id                                                                                         6499
# listing_url                                                   https://www.airbnb.com/rooms/6499
# scrape_id                                                                        20230911050651
# last_scraped                                                                         2023-09-11
# source                                                                              city scrape
# name                                          Rental unit in Lisbon · ★4.52 · 1 bedroom · 3 ...
# description                                   This apartment is all about Location, next to ...
# neighborhood_overview                         To get  to the city center, tram 15 stops in f...
# picture_url                                   https://a0.muscache.com/pictures/6422ee92-c84e...
# host_id                                                                                   14455
# host_url                                                https://www.airbnb.com/users/show/14455
# host_name                                                                                 Bruno
# host_since                                                                           2009-04-22
# host_location                                                                 Brussels, Belgium
# host_about                                    I am Bruno Luis, a Portuguese living in The Ha...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                       100%
# host_is_superhost                                                                             f
# host_thumbnail_url                            https://a0.muscache.com/im/users/14455/profile...
# host_picture_url                              https://a0.muscache.com/im/users/14455/profile...
# host_neighbourhood                                                                          NaN
# host_listings_count                                                                         1.0
# host_total_listings_count                                                                   2.0
# host_verifications                                                           ['email', 'phone']
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                                  Lisbon, Portugal
# neighbourhood_cleansed                                                                     Belm
# neighbourhood_group_cleansed                                                             Lisboa
# latitude                                                                                38.6975
# longitude                                                                              -9.19768
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                  3
# bathrooms                                                                                   NaN
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        3.0
# amenities                                     ["Shampoo", "River view", "Dishes and silverwa...
# price                                                                                    $79.00
# minimum_nights                                                                                3
# maximum_nights                                                                              365
# minimum_minimum_nights                                                                        3
# maximum_minimum_nights                                                                        3
# minimum_maximum_nights                                                                      365
# maximum_maximum_nights                                                                      365
# minimum_nights_avg_ntm                                                                      3.0
# maximum_nights_avg_ntm                                                                    365.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               4
# availability_60                                                                               4
# availability_90                                                                              13
# availability_365                                                                            248
# calendar_last_scraped                                                                2023-09-11
# number_of_reviews                                                                            60
# number_of_reviews_ltm                                                                        15
# number_of_reviews_l30d                                                                        2
# first_review                                                                         2014-09-02
# last_review                                                                          2023-08-26
# review_scores_rating                                                                       4.52
# review_scores_accuracy                                                                     4.42
# review_scores_cleanliness                                                                  4.45
# review_scores_checkin                                                                      4.83
# review_scores_communication                                                                4.93
# review_scores_location                                                                     4.79
# review_scores_value                                                                        4.41
# license                                                                                     NaN
# instant_bookable                                                                              t
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          0.55
#
#                                                                                               1  \
# id                                                                                        25659
# listing_url                                                  https://www.airbnb.com/rooms/25659
# scrape_id                                                                        20230911050651
# last_scraped                                                                         2023-09-12
# source                                                                              city scrape
# name                                          Rental unit in Lisboa · ★4.81 · 1 bedroom · 1 ...
# description                                   Most traditional, charming neighborhood of Lis...
# neighborhood_overview                         Alfama is the oldest and most picturesque quar...
# picture_url                                   https://a0.muscache.com/pictures/miso/Hosting-...
# host_id                                                                                  107347
# host_url                                               https://www.airbnb.com/users/show/107347
# host_name                                                                                 Ellie
# host_since                                                                           2010-04-12
# host_location                                                                  Lisbon, Portugal
# host_about                                    Woman Artist living in Lisbon many years. I li...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                       100%
# host_is_superhost                                                                             t
# host_thumbnail_url                            https://a0.muscache.com/im/pictures/user/8568e...
# host_picture_url                              https://a0.muscache.com/im/pictures/user/8568e...
# host_neighbourhood                                                                       Alfama
# host_listings_count                                                                         1.0
# host_total_listings_count                                                                   2.0
# host_verifications                                                           ['email', 'phone']
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                                  Lisboa, Portugal
# neighbourhood_cleansed                                                        Santa Maria Maior
# neighbourhood_group_cleansed                                                             Lisboa
# latitude                                                                               38.71241
# longitude                                                                              -9.12706
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                  3
# bathrooms                                                                                   NaN
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        1.0
# amenities                                     ["Smoke alarm", "Shampoo", "Dishes and silverw...
# price                                                                                    $88.00
# minimum_nights                                                                                2
# maximum_nights                                                                               14
# minimum_minimum_nights                                                                        2
# maximum_minimum_nights                                                                        7
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      2.1
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               5
# availability_60                                                                              16
# availability_90                                                                              46
# availability_365                                                                            318
# calendar_last_scraped                                                                2023-09-12
# number_of_reviews                                                                           193
# number_of_reviews_ltm                                                                        27
# number_of_reviews_l30d                                                                        3
# first_review                                                                         2014-04-24
# last_review                                                                          2023-08-29
# review_scores_rating                                                                       4.81
# review_scores_accuracy                                                                     4.88
# review_scores_cleanliness                                                                  4.87
# review_scores_checkin                                                                      4.94
# review_scores_communication                                                                4.95
# review_scores_location                                                                     4.88
# review_scores_value                                                                        4.82
# license                                                                               56539/AL.
# instant_bookable                                                                              t
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          1.69
#
#                                                                                               2  \
# id                                                                                       119120
# listing_url                                                 https://www.airbnb.com/rooms/119120
# scrape_id                                                                        20230911050651
# last_scraped                                                                         2023-09-12
# source                                                                              city scrape
# name                                          Rental unit in Lisbon · ★4.89 · 2 bedrooms · 2...
# description                                   Charming two bedroom with City and River Views...
# neighborhood_overview                         Lapa is a unique neighborhood with façades cov...
# picture_url                                   https://a0.muscache.com/pictures/1012151/4bc3c...
# host_id                                                                                  387186
# host_url                                               https://www.airbnb.com/users/show/387186
# host_name                                                                                  Nuno
# host_since                                                                           2011-02-11
# host_location                                                                  Lisbon, Portugal
# host_about                                                               Lisbon based architect
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                        99%
# host_is_superhost                                                                             t
# host_thumbnail_url                            https://a0.muscache.com/im/users/387186/profil...
# host_picture_url                              https://a0.muscache.com/im/users/387186/profil...
# host_neighbourhood                                                                Estrella/Lapa
# host_listings_count                                                                         8.0
# host_total_listings_count                                                                   8.0
# host_verifications                                                           ['email', 'phone']
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                                  Lisbon, Portugal
# neighbourhood_cleansed                                                                  Estrela
# neighbourhood_group_cleansed                                                             Lisboa
# latitude                                                                               38.70927
# longitude                                                                              -9.16122
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                  4
# bathrooms                                                                                   NaN
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    2.0
# beds                                                                                        2.0
# amenities                                     ["Smoke alarm", "Shampoo", "River view", "Dish...
# price                                                                                   $135.00
# minimum_nights                                                                                3
# maximum_nights                                                                                7
# minimum_minimum_nights                                                                        2
# maximum_minimum_nights                                                                        3
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      3.0
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               8
# availability_60                                                                               8
# availability_90                                                                               8
# availability_365                                                                              8
# calendar_last_scraped                                                                2023-09-12
# number_of_reviews                                                                           331
# number_of_reviews_ltm                                                                        45
# number_of_reviews_l30d                                                                        2
# first_review                                                                         2011-08-08
# last_review                                                                          2023-08-23
# review_scores_rating                                                                       4.89
# review_scores_accuracy                                                                     4.91
# review_scores_cleanliness                                                                  4.93
# review_scores_checkin                                                                      4.94
# review_scores_communication                                                                4.97
# review_scores_location                                                                     4.75
# review_scores_value                                                                        4.83
# license                                                                                 6820/AL
# instant_bookable                                                                              f
# calculated_host_listings_count                                                                8
# calculated_host_listings_count_entire_homes                                                   8
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          2.25
#
#                                                                                               3  \
# id                                                                                        29248
# listing_url                                                  https://www.airbnb.com/rooms/29248
# scrape_id                                                                        20230911050651
# last_scraped                                                                         2023-09-12
# source                                                                              city scrape
# name                                          Rental unit in Lisbon · ★4.57 · 1 bedroom · 2 ...
# description                                   <b>The space</b><br />Located in the city cent...
# neighborhood_overview                                                                       NaN
# picture_url                                   https://a0.muscache.com/pictures/4212cc65-2046...
# host_id                                                                                  125768
# host_url                                               https://www.airbnb.com/users/show/125768
# host_name                                                                               Bárbara
# host_since                                                                           2010-05-16
# host_location                                                                  Lisbon, Portugal
# host_about                                    Hi!\r\n\r\nI'm a marketeer working for a susta...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                        99%
# host_is_superhost                                                                             t
# host_thumbnail_url                            https://a0.muscache.com/im/pictures/user/d5c5c...
# host_picture_url                              https://a0.muscache.com/im/pictures/user/d5c5c...
# host_neighbourhood                                                                       Alfama
# host_listings_count                                                                         7.0
# host_total_listings_count                                                                  10.0
# host_verifications                                             ['email', 'phone', 'work_email']
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                                               NaN
# neighbourhood_cleansed                                                        Santa Maria Maior
# neighbourhood_group_cleansed                                                             Lisboa
# latitude                                                                               38.71082
# longitude                                                                              -9.12719
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                  4
# bathrooms                                                                                   NaN
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        2.0
# amenities                                     ["Dishes and silverware", "River view", "Refri...
# price                                                                                   $128.00
# minimum_nights                                                                                5
# maximum_nights                                                                             1125
# minimum_minimum_nights                                                                        2
# maximum_minimum_nights                                                                        5
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      2.4
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               0
# availability_60                                                                               0
# availability_90                                                                               0
# availability_365                                                                            160
# calendar_last_scraped                                                                2023-09-12
# number_of_reviews                                                                           372
# number_of_reviews_ltm                                                                        19
# number_of_reviews_l30d                                                                        0
# first_review                                                                         2011-01-01
# last_review                                                                          2023-07-15
# review_scores_rating                                                                       4.57
# review_scores_accuracy                                                                     4.63
# review_scores_cleanliness                                                                  4.39
# review_scores_checkin                                                                      4.63
# review_scores_communication                                                                4.75
# review_scores_location                                                                     4.83
# review_scores_value                                                                        4.61
# license                                                                                23535/AL
# instant_bookable                                                                              t
# calculated_host_listings_count                                                                5
# calculated_host_listings_count_entire_homes                                                   5
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          2.41
#
#                                                                                               5
# id                                                                                        29396
# listing_url                                                  https://www.airbnb.com/rooms/29396
# scrape_id                                                                        20230911050651
# last_scraped                                                                         2023-09-12
# source                                                                              city scrape
# name                                          Rental unit in Lisbon · ★4.79 · 1 bedroom · 1 ...
# description                                   Feel at home in the historic centre of Lisbon....
# neighborhood_overview                         Great neighborhood in the old part of town. Am...
# picture_url                                   https://a0.muscache.com/pictures/163913/7d622c...
# host_id                                                                                  126415
# host_url                                               https://www.airbnb.com/users/show/126415
# host_name                                                                                Mónica
# host_since                                                                           2010-05-17
# host_location                                                                  Lisbon, Portugal
# host_about                                    Pretty apartment  with a terrific view combine...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                       100%
# host_is_superhost                                                                             f
# host_thumbnail_url                            https://a0.muscache.com/im/users/126415/profil...
# host_picture_url                              https://a0.muscache.com/im/users/126415/profil...
# host_neighbourhood                                                                          NaN
# host_listings_count                                                                         1.0
# host_total_listings_count                                                                   1.0
# host_verifications                                                           ['email', 'phone']
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                                  Lisbon, Portugal
# neighbourhood_cleansed                                                        Santa Maria Maior
# neighbourhood_group_cleansed                                                             Lisboa
# latitude                                                                               38.71156
# longitude                                                                              -9.12987
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                  4
# bathrooms                                                                                   NaN
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    1.0
# beds                                                                                        1.0
# amenities                                     ["Dishes and silverware", "Books and reading m...
# price                                                                                    $63.00
# minimum_nights                                                                                2
# maximum_nights                                                                             1125
# minimum_minimum_nights                                                                        2
# maximum_minimum_nights                                                                        4
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                      2.0
# maximum_nights_avg_ntm                                                                   1125.0
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                               4
# availability_60                                                                               4
# availability_90                                                                              14
# availability_365                                                                            250
# calendar_last_scraped                                                                2023-09-12
# number_of_reviews                                                                           381
# number_of_reviews_ltm                                                                        42
# number_of_reviews_l30d                                                                        1
# first_review                                                                         2012-05-22
# last_review                                                                          2023-08-18
# review_scores_rating                                                                       4.79
# review_scores_accuracy                                                                     4.83
# review_scores_cleanliness                                                                  4.77
# review_scores_checkin                                                                      4.88
# review_scores_communication                                                                4.91
# review_scores_location                                                                     4.87
# review_scores_value                                                                        4.75
# license                                                                                28737/AL
# instant_bookable                                                                              t
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          2.77

# %% [markdown]
# # Data Cleaning and Data Preparation
# 1. cleaning `amenities` columns (grouping by category using amenities_cleaned_df) # this was done seperately as code was very long to include
# 2. getting number of bathrooms from `bathroom_texts`

# %%
main_df['amenities'][0] #exploring our amenities columns
# Out:
# '["Shampoo", "River view", "Dishes and silverware", "Dining table", "Stove", "Coffee maker", "Paid street parking off premises", "Kitchen", "Microwave", "Freezer", "Bed linens", "Paid parking on premises", "Laundromat nearby", "Oven", "Host greets you", "Carbon monoxide alarm", "Mini fridge", "Ethernet connection", "TV with standard cable", "First aid kit", "Hot water", "Extra pillows and blankets", "Cooking basics", "Wifi", "Essentials", "Cleaning products", "Fire extinguisher", "Free street parking", "Room-darkening shades", "Free washer \\u2013 In unit", "Long term stays allowed"]'

# %%
# cleaning the amenities column
main_df["amenities"] = main_df["amenities"].astype(str).str.strip("[]").str.replace('"', "").str.split(",")

# %%
# cleaning the amenities column
old_value1 = '\\u2019n '
old_value2 = '\\u2013 '
old_value3 = '\\'
new_value = ''


main_df['amenities'] = main_df['amenities'].apply(lambda x: [item.replace(old_value1, new_value) for item in x])
main_df['amenities'] = main_df['amenities'].apply(lambda x: [item.replace(old_value2, new_value) for item in x])
main_df['amenities'] = main_df['amenities'].apply(lambda x: [item.replace(old_value3, new_value) for item in x])

# %%
# replacing and mapping values as defined by me in the unique cleaned amenities dataset

replacement_dict = dict(zip(amenities_cleaned_df['original'], amenities_cleaned_df['new']))

main_df['amenities_cleaned'] = main_df['amenities'].apply(lambda x: [replacement_dict[val] if val in replacement_dict else val for val in x])

print(sorted(main_df["amenities_cleaned"].explode().unique()))
# Out:
# ['', 'airconditioning', 'backyard', 'bbq', 'beachaccess', 'bodysoap', 'breakfast', 'cabletv', 'closet', 'coffeemaker', 'conditioner', 'dishwasher', 'dryer', 'elevator', 'essentials', 'fireextinguisher', 'firstaidkit', 'freeparking', 'gameconsole', 'gym', 'hairdryer', 'hangers', 'hottub', 'indoorfireplace', 'keypad', 'kidfriendly', 'kitchen', 'lockbox', 'luxuryamenities', 'others', 'outdooramenities', 'paidparking', 'petfriendly', 'pool', 'privateentrance', 'privatelivingroom', 'refrigerator', 'securitycameras', 'selfcheckin', 'shampoo', 'smokedetector', 'smokingallowed', 'soundsystem', 'tv', 'washer', 'wifi', 'windowview', 'workspace']

# %%
# extracting bathrooms from bathroom text

def extract_bathrooms(text):
    match = re.match(r'^([\d.]+)\s*baths?', str(text))
    if match:
        return float(match.group(1))
    else:
        return 0

main_df['n_bathrooms'] = main_df['bathrooms_text'].apply(extract_bathrooms)

# %% [markdown]
# #### Filtering out irrelevant columns and renaming the relevant ones for better information representing

# %%
columns_to_keep = ['property_type','room_type','price','accommodates', 'beds','bedrooms','n_bathrooms',
                   'review_scores_rating', 'host_is_superhost','number_of_reviews', 'minimum_nights', 'maximum_nights', 
                   'reviews_per_month','neighbourhood_cleansed','neighbourhood_group_cleansed','instant_bookable','amenities_cleaned']

filtered_df= main_df[columns_to_keep]

column_renaming = {
    'property_type':'f_property_type',
    'room_type':'f_room_type',
    'accommodates': 'n_accommodates',
    'beds': 'n_beds',
    'bedrooms':'n_bedrooms',
    'minimum_nights': 'n_minimum_nights',
    'maximum_nights': 'n_maximum_nights',
    'instant_bookable': 'd_instant_bookable',
    'host_is_superhost':'d_host_is_superhost',
    'number_of_reviews': 'n_number_of_reviews',
    'reviews_per_month': 'n_reviews_per_month',
    'review_scores_rating': 'n_review_scores_rating',
    'neighbourhood_cleansed': 'f_neighbourhood_cleansed',
    'neighbourhood_group_cleansed': 'f_neighbourhood_group_cleansed',    
}

filtered_df.rename(columns=column_renaming, inplace=True)

# %% [markdown]
# #### Transforming variables and cleaning our dependant variable
# 1. `property type` to category
# 2. `room type` to category
# 3. `neighbourhood cleansed` to category
# 4. `instant bookable` to 1 0
# 5. `host is super` host to 1 0
# 6. `price` cleaning

# %%
filtered_df["f_property_type"] = filtered_df["f_property_type"].astype("category") # category column for modelling
filtered_df["f_room_type"] = filtered_df["f_room_type"].astype("category") # category column for modelling
filtered_df["f_neighbourhood_cleansed"] = filtered_df["f_neighbourhood_cleansed"].astype("category") # category column for modelling
filtered_df["f_neighbourhood_group_cleansed"] = filtered_df["f_neighbourhood_group_cleansed"].astype("category") # category column for modelling


filtered_df['d_instant_bookable'] = np.where(filtered_df['d_instant_bookable'] == 't', '1', '0') .astype(int) # changing to 1 and 0
filtered_df['d_host_is_superhost'] = np.where(filtered_df['d_host_is_superhost'] == 't', '1', '0') .astype(int) # changing to 1 and 0


# cleaning price variable
filtered_df['price'] = filtered_df['price'].replace({'\$': '', ',': ''}, regex=True).astype(float)
filtered_df = filtered_df.dropna(subset=['price'])
filtered_df = filtered_df[filtered_df['price'] > 0]
filtered_df['price'] = filtered_df['price'].astype(int)

# %%
# checking for missing values in columns
for col in filtered_df.columns:
    missing_values_col = filtered_df[col].isnull().sum()
    print(f"Missing values for {col}: {missing_values_col}")
# Out:
# Missing values for f_property_type: 0
# Missing values for f_room_type: 0
# Missing values for price: 0
# Missing values for n_accommodates: 0
# Missing values for n_beds: 54
# Missing values for n_bedrooms: 746
# Missing values for n_bathrooms: 0
# Missing values for n_review_scores_rating: 1251
# Missing values for d_host_is_superhost: 0
# Missing values for n_number_of_reviews: 0
# Missing values for n_minimum_nights: 0
# Missing values for n_maximum_nights: 0
# Missing values for n_reviews_per_month: 1251
# Missing values for f_neighbourhood_cleansed: 0
# Missing values for f_neighbourhood_group_cleansed: 0
# Missing values for d_instant_bookable: 0
# Missing values for amenities_cleaned: 0

# %%
# since missing values are low in number, I am dropping them instead of making flag columns or imputing them

filtered_df.dropna(subset=['n_review_scores_rating','n_bedrooms','n_beds'], inplace=True)

for col in filtered_df.columns:
    missing_values_col = filtered_df[col].isnull().sum()
    print(f"Missing values for {col}: {missing_values_col}")
# Out:
# Missing values for f_property_type: 0
# Missing values for f_room_type: 0
# Missing values for price: 0
# Missing values for n_accommodates: 0
# Missing values for n_beds: 0
# Missing values for n_bedrooms: 0
# Missing values for n_bathrooms: 0
# Missing values for n_review_scores_rating: 0
# Missing values for d_host_is_superhost: 0
# Missing values for n_number_of_reviews: 0
# Missing values for n_minimum_nights: 0
# Missing values for n_maximum_nights: 0
# Missing values for n_reviews_per_month: 0
# Missing values for f_neighbourhood_cleansed: 0
# Missing values for f_neighbourhood_group_cleansed: 0
# Missing values for d_instant_bookable: 0
# Missing values for amenities_cleaned: 0

# %%
# Creating amenities columns from each amenity for each listing
unique_amenities = set()
for amenities_list in filtered_df['amenities_cleaned']:
    unique_amenities.update(amenities_list)

for amenity in unique_amenities:
    filtered_df['d_' + amenity] = filtered_df['amenities_cleaned'].apply(lambda x: 1 if amenity in x else 0)

# %%
# Extra check to ensure our dummy columns are integer columns

dummy_cols = filtered_df.filter(regex='^d_').columns
filtered_df[dummy_cols] = filtered_df[dummy_cols].fillna(0).astype(int)

# %%
# Dropping irrelevant columns for a cleaner dataframe

columns_to_drop = ['d_','amenities_cleaned']
clean_df = filtered_df.drop(columns_to_drop, axis=1)

# %%
# Final dataframe for use
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12356 entries, 0 to 22535
# Data columns (total 63 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   f_property_type                 12356 non-null  category
#  1   f_room_type                     12356 non-null  category
#  2   price                           12356 non-null  int32
#  3   n_accommodates                  12356 non-null  int64
#  4   n_beds                          12356 non-null  float64
#  5   n_bedrooms                      12356 non-null  float64
#  6   n_bathrooms                     12356 non-null  float64
#  7   n_review_scores_rating          12356 non-null  float64
#  8   d_host_is_superhost             12356 non-null  int32
#  9   n_number_of_reviews             12356 non-null  int64
#  10  n_minimum_nights                12356 non-null  int64
#  11  n_maximum_nights                12356 non-null  int64
#  12  n_reviews_per_month             12356 non-null  float64
#  13  f_neighbourhood_cleansed        12356 non-null  category
#  14  f_neighbourhood_group_cleansed  12356 non-null  category
#  15  d_instant_bookable              12356 non-null  int32
#  16  d_windowview                    12356 non-null  int32
#  17  d_pool                          12356 non-null  int32
#  18  d_luxuryamenities               12356 non-null  int32
#  19  d_gameconsole                   12356 non-null  int32
#  20  d_closet                        12356 non-null  int32
#  21  d_paidparking                   12356 non-null  int32
#  22  d_gym                           12356 non-null  int32
#  23  d_smokingallowed                12356 non-null  int32
#  24  d_airconditioning               12356 non-null  int32
#  25  d_soundsystem                   12356 non-null  int32
#  26  d_coffeemaker                   12356 non-null  int32
#  27  d_washer                        12356 non-null  int32
#  28  d_firstaidkit                   12356 non-null  int32
#  29  d_conditioner                   12356 non-null  int32
#  30  d_privatelivingroom             12356 non-null  int32
#  31  d_wifi                          12356 non-null  int32
#  32  d_privateentrance               12356 non-null  int32
#  33  d_dryer                         12356 non-null  int32
#  34  d_bbq                           12356 non-null  int32
#  35  d_hairdryer                     12356 non-null  int32
#  36  d_breakfast                     12356 non-null  int32
#  37  d_essentials                    12356 non-null  int32
#  38  d_indoorfireplace               12356 non-null  int32
#  39  d_tv                            12356 non-null  int32
#  40  d_elevator                      12356 non-null  int32
#  41  d_others                        12356 non-null  int32
#  42  d_hangers                       12356 non-null  int32
#  43  d_backyard                      12356 non-null  int32
#  44  d_hottub                        12356 non-null  int32
#  45  d_dishwasher                    12356 non-null  int32
#  46  d_petfriendly                   12356 non-null  int32
#  47  d_freeparking                   12356 non-null  int32
#  48  d_fireextinguisher              12356 non-null  int32
#  49  d_bodysoap                      12356 non-null  int32
#  50  d_refrigerator                  12356 non-null  int32
#  51  d_shampoo                       12356 non-null  int32
#  52  d_workspace                     12356 non-null  int32
#  53  d_kitchen                       12356 non-null  int32
#  54  d_cabletv                       12356 non-null  int32
#  55  d_kidfriendly                   12356 non-null  int32
#  56  d_securitycameras               12356 non-null  int32
#  57  d_selfcheckin                   12356 non-null  int32
#  58  d_lockbox                       12356 non-null  int32
#  59  d_smokedetector                 12356 non-null  int32
#  60  d_keypad                        12356 non-null  int32
#  61  d_beachaccess                   12356 non-null  int32
#  62  d_outdooramenities              12356 non-null  int32
# dtypes: category(4), float64(5), int32(50), int64(4)
# memory usage: 3.4 MB

# %% [markdown]
# #### Combining property types on my definition for better information

# %%
clean_df['f_property_type'] = clean_df['f_property_type'].replace({'Entire rental unit': 'Apartment',
'Entire home': 'Home',
'Entire condo': 'Condo',
'Entire serviced apartment': 'Apartment',
'Entire loft': 'Loft',
'Entire villa': 'Loft',
'Entire townhouse': 'Home',
'Entire cottage': 'Home',
'Entire vacation home': 'Home',
'Entire guesthouse': 'Home',
'Entire guest suite': 'Apartment',
'Entire cabin': 'Condo',
'Entire place': 'Apartment',
'Entire chalet': 'Home',
'Entire bungalow':'Home',
'Entire bed and breakfast': 'Home',
'Entire hostel': 'Condo',
'Entire home/apt': 'Home'})

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Exploring our dependant variable and removing extreme values so my models are better

# %%
clean_df.shape
# Out:
# (12356, 63)

# %%
clean_df['price'].describe(percentiles = [0.85,0.9,0.95,0.96,0.97,0.98,0.99])
# Out:
# count    12356.000000
# mean       148.132001
# std        683.564224
# min         10.000000
# 50%        120.000000
# 85%        195.000000
# 90%        222.000000
# 95%        276.000000
# 96%        295.000000
# 97%        316.350000
# 98%        357.000000
# 99%        446.000000
# max      74110.000000
# Name: price, dtype: float64

# %%
# dropping values over 276 (95% percentile) ~ 700 values
clean_df = clean_df.loc[clean_df['price'] <= 276]

# %%
clean_df.shape
# Out:
# (11743, 63)

# %%
clean_df['price'].describe(percentiles = [0.85,0.9,0.95,0.96,0.97,0.98,0.99])
# Out:
# count    11743.000000
# mean       125.865792
# std         48.962625
# min         10.000000
# 50%        118.000000
# 85%        179.000000
# 90%        198.000000
# 95%        225.000000
# 96%        233.000000
# 97%        241.000000
# 98%        250.000000
# 99%        260.000000
# max        276.000000
# Name: price, dtype: float64

# %%
plot = ggplot(clean_df, aes(x='price', y="stat(count)/sum(stat(count))")) + \
       geom_histogram(binwidth=12, fill='#008080', color='white') + \
       labs(title="Distribution of Price", x="Price", y="Percentage") + \
       theme_minimal() + \
       theme(panel_grid_major=element_blank(), panel_grid_minor=element_blank(), 
             plot_title=element_text(size=20), axis_text=element_text(size=12), axis_title=element_text(size=14), 
             figure_size=(8, 6)) + \
       scale_y_continuous(labels=percent_format())

print(plot)

# %%
clean_df['f_property_type'].value_counts()
# Out:
# f_property_type
# Apartment    9751
# Home         1095
# Condo         608
# Loft          289
# Name: count, dtype: int64

# %%
clean_df['n_accommodates'].value_counts()
# Out:
# n_accommodates
# 4    4966
# 2    2615
# 6    1929
# 3    1222
# 5    1011
# Name: count, dtype: int64

# %%
clean_df['f_neighbourhood_group_cleansed'].value_counts()
# Out:
# f_neighbourhood_group_cleansed
# Lisboa                   8537
# Cascais                  1058
# Mafra                     683
# Sintra                    627
# Oeiras                    227
# Lourinh                   189
# Torres Vedras             145
# Amadora                    87
# Loures                     85
# Odivelas                   39
# Alenquer                   21
# Vila Franca De Xira        15
# Cadaval                    14
# Sobral De Monte Agrao       9
# Arruda Dos Vinhos           4
# Azambuja                    3
# Name: count, dtype: int64

# %%
clean_df.describe().T.round(2)
# Out:
#                           count    mean     std    min    25%     50%  \
# price                   11743.0  125.87   48.96  10.00  90.00  118.00
# n_accommodates          11743.0    3.87    1.31   2.00   3.00    4.00
# n_beds                  11743.0    2.31    1.12   1.00   1.00    2.00
# n_bedrooms              11743.0    1.61    0.69   1.00   1.00    2.00
# n_bathrooms             11743.0    1.24    0.47   0.00   1.00    1.00
# n_review_scores_rating  11743.0    4.65    0.41   0.00   4.55    4.75
# d_host_is_superhost     11743.0    0.32    0.46   0.00   0.00    0.00
# n_number_of_reviews     11743.0   78.18   98.05   1.00  12.00   39.00
# n_minimum_nights        11743.0    3.88   16.13   1.00   2.00    2.00
# n_maximum_nights        11743.0  590.12  586.57   2.00  62.00  365.00
# n_reviews_per_month     11743.0    1.67    1.41   0.01   0.57    1.33
# d_instant_bookable      11743.0    0.58    0.49   0.00   0.00    1.00
# d_windowview            11743.0    0.25    0.44   0.00   0.00    0.00
# d_pool                  11743.0    0.07    0.25   0.00   0.00    0.00
# d_luxuryamenities       11743.0    0.54    0.50   0.00   0.00    1.00
# d_gameconsole           11743.0    0.01    0.08   0.00   0.00    0.00
# d_closet                11743.0    0.43    0.49   0.00   0.00    0.00
# d_paidparking           11743.0    0.35    0.48   0.00   0.00    0.00
# d_gym                   11743.0    0.02    0.15   0.00   0.00    0.00
# d_smokingallowed        11743.0    0.07    0.26   0.00   0.00    0.00
# d_airconditioning       11743.0    0.69    0.46   0.00   0.00    1.00
# d_soundsystem           11743.0    0.04    0.21   0.00   0.00    0.00
# d_coffeemaker           11743.0    0.82    0.39   0.00   1.00    1.00
# d_washer                11743.0    0.77    0.42   0.00   1.00    1.00
# d_firstaidkit           11743.0    0.78    0.41   0.00   1.00    1.00
# d_conditioner           11743.0    0.06    0.24   0.00   0.00    0.00
# d_privatelivingroom     11743.0    0.37    0.48   0.00   0.00    0.00
# d_wifi                  11743.0    0.99    0.10   0.00   1.00    1.00
# d_privateentrance       11743.0    0.28    0.45   0.00   0.00    0.00
# d_dryer                 11743.0    0.22    0.41   0.00   0.00    0.00
# d_bbq                   11743.0    0.09    0.29   0.00   0.00    0.00
# d_hairdryer             11743.0    0.89    0.31   0.00   1.00    1.00
# d_breakfast             11743.0    0.01    0.08   0.00   0.00    0.00
# d_essentials            11743.0    0.97    0.17   0.00   1.00    1.00
# d_indoorfireplace       11743.0    0.07    0.26   0.00   0.00    0.00
# d_tv                    11743.0    0.48    0.50   0.00   0.00    0.00
# d_elevator              11743.0    0.22    0.42   0.00   0.00    0.00
# d_others                11743.0    0.87    0.34   0.00   1.00    1.00
# d_hangers               11743.0    0.84    0.37   0.00   1.00    1.00
# d_backyard              11743.0    0.16    0.37   0.00   0.00    0.00
# d_hottub                11743.0    0.01    0.11   0.00   0.00    0.00
# d_dishwasher            11743.0    0.48    0.50   0.00   0.00    0.00
# d_petfriendly           11743.0    0.14    0.35   0.00   0.00    0.00
# d_freeparking           11743.0    0.35    0.48   0.00   0.00    0.00
# d_fireextinguisher      11743.0    0.78    0.41   0.00   1.00    1.00
# d_bodysoap              11743.0    0.43    0.49   0.00   0.00    0.00
# d_refrigerator          11743.0    0.88    0.32   0.00   1.00    1.00
# d_shampoo               11743.0    0.59    0.49   0.00   0.00    1.00
# d_workspace             11743.0    0.34    0.47   0.00   0.00    0.00
# d_kitchen               11743.0    0.99    0.08   0.00   1.00    1.00
# d_cabletv               11743.0    0.48    0.50   0.00   0.00    0.00
# d_kidfriendly           11743.0    0.52    0.50   0.00   0.00    1.00
# d_securitycameras       11743.0    0.05    0.22   0.00   0.00    0.00
# d_selfcheckin           11743.0    0.35    0.48   0.00   0.00    0.00
# d_lockbox               11743.0    0.36    0.48   0.00   0.00    0.00
# d_smokedetector         11743.0    0.36    0.48   0.00   0.00    0.00
# d_keypad                11743.0    0.06    0.25   0.00   0.00    0.00
# d_beachaccess           11743.0    0.15    0.35   0.00   0.00    0.00
# d_outdooramenities      11743.0    0.46    0.50   0.00   0.00    0.00
#
#                             75%       max
# price                    153.00    276.00
# n_accommodates             5.00      6.00
# n_beds                     3.00     11.00
# n_bedrooms                 2.00      6.00
# n_bathrooms                1.00      4.50
# n_review_scores_rating     4.89      5.00
# d_host_is_superhost        1.00      1.00
# n_number_of_reviews      107.00   1002.00
# n_minimum_nights           3.00   1000.00
# n_maximum_nights        1125.00  36180.00
# n_reviews_per_month        2.42     16.14
# d_instant_bookable         1.00      1.00
# d_windowview               1.00      1.00
# d_pool                     0.00      1.00
# d_luxuryamenities          1.00      1.00
# d_gameconsole              0.00      1.00
# d_closet                   1.00      1.00
# d_paidparking              1.00      1.00
# d_gym                      0.00      1.00
# d_smokingallowed           0.00      1.00
# d_airconditioning          1.00      1.00
# d_soundsystem              0.00      1.00
# d_coffeemaker              1.00      1.00
# d_washer                   1.00      1.00
# d_firstaidkit              1.00      1.00
# d_conditioner              0.00      1.00
# d_privatelivingroom        1.00      1.00
# d_wifi                     1.00      1.00
# d_privateentrance          1.00      1.00
# d_dryer                    0.00      1.00
# d_bbq                      0.00      1.00
# d_hairdryer                1.00      1.00
# d_breakfast                0.00      1.00
# d_essentials               1.00      1.00
# d_indoorfireplace          0.00      1.00
# d_tv                       1.00      1.00
# d_elevator                 0.00      1.00
# d_others                   1.00      1.00
# d_hangers                  1.00      1.00
# d_backyard                 0.00      1.00
# d_hottub                   0.00      1.00
# d_dishwasher               1.00      1.00
# d_petfriendly              0.00      1.00
# d_freeparking              1.00      1.00
# d_fireextinguisher         1.00      1.00
# d_bodysoap                 1.00      1.00
# d_refrigerator             1.00      1.00
# d_shampoo                  1.00      1.00
# d_workspace                1.00      1.00
# d_kitchen                  1.00      1.00
# d_cabletv                  1.00      1.00
# d_kidfriendly              1.00      1.00
# d_securitycameras          0.00      1.00
# d_selfcheckin              1.00      1.00
# d_lockbox                  1.00      1.00
# d_smokedetector            1.00      1.00
# d_keypad                   0.00      1.00
# d_beachaccess              0.00      1.00
# d_outdooramenities         1.00      1.00

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Shortlisting variables using LASSO
#     1. Grouping Variables by topic for easy coding

# %%
# Seperating my variables by topic

## basic variables
basic_vars = ["f_property_type","n_accommodates","n_bedrooms","n_bathrooms","n_beds","f_neighbourhood_cleansed"]

## reviews
reviews = ["n_number_of_reviews","n_review_scores_rating",]

## dummies
dummies = list(clean_df.filter(regex="^d_.*"))


## interactions

# for interactions I interacted property types and accommodates with all the dummies
interactions = []

for dummy_col in clean_df.filter(regex="^d_.*"):
    
    interaction_f = 'f_property_type' + '*' + dummy_col + ' + '
    interactions.append(interaction_f)
    
    interaction_n = 'n_accommodates' + '*' + dummy_col + ' + '
    interactions.append(interaction_n)

all_interactions = ''.join(interactions)
all_interactions = all_interactions[:-3]

# %%
# Checking if theres need of adding a property and accommodates interactions
(
    ggplot(
        clean_df,
        aes(
            x="factor(n_accommodates)",
            y="price",
            # fill="factor(f_property_type)",
            color="factor(f_property_type)",
        ),
    )
    + geom_boxplot(alpha=0.8, na_rm=True, outlier_shape="", width=0.9, stat="boxplot")
    + scale_color_manual(name="Property Type", values=(color[0], color[1],color[2], color[3]))
    + scale_fill_manual(name="", values=(color[0], color[1], color[2], color[3]))
    + labs(x="Accomodates", y="Price", color="Property Type")
    + scale_y_continuous(expand=(0.01, 0.01), limits=(0, 300), breaks=seq(0, 401, 50))
    + theme_minimal() + 
       theme(legend_position=(0.3, 0.9),panel_grid_major=element_blank(), panel_grid_minor=element_blank(), 
             plot_title=element_text(size=20), axis_text=element_text(size=12), axis_title=element_text(size=14), 
             figure_size=(8, 6))
)
# Out:
# <Figure Size: (800 x 600)>

# %% [markdown]
# #### As per my decision, I chose not add interactions between property type and accommodates

# %%
model1="~"+"+".join(basic_vars)
model2="~"+"+".join(basic_vars)+"+"+"+".join(reviews)+"+"+"+".join(dummies)
model3="~"+"+".join(basic_vars)+"+"+"+".join(reviews)+"+"+"+".join(dummies)+"+"+all_interactions


predictors = basic_vars + reviews + dummies

# %%
total_variables = model3.split("+")

num_words = len(total_variables)

print("Number of variables before LASSO: ", num_words)
# Out:
# Number of variables before LASSO:  155

# %% [markdown]
# #### Note that model 3 is the most complex with all the interactions, and will be used in LASSO to shortlist our variables for usage

# %% [markdown]
# *Using Naive Grid Search method*

# %%
cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=1)
y, X = patsy.dmatrices("price" + model3, clean_df)

# %%
smp_size = round(0.2 * clean_df.shape[0])-1
smp_size
# Out:
# 2348

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=smp_size, random_state=10
)

lambdas = [i/100 for i in range(5, 100,5)]

train_r_squared = np.zeros(len(lambdas))
test_r_squared = np.zeros(len(lambdas))

pred_num = X.shape[1]
coeff_a = np.zeros((len(lambdas), pred_num))

# %%
for ind, i in enumerate(lambdas):
    print(f"Run: {str(ind).rjust(2)}, lambda: {i:.2f}, start: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    reg = Lasso(alpha = i, random_state= 20240115)
    reg.fit(X_train, y_train)
    results = cross_val_score(reg, X, y, cv=cv, scoring="r2")

    train_r_squared[ind] = reg.score(X_train, y_train)    
    test_r_squared[ind] = reg.score(X_test, y_test)
# Out:
# Run:  0, lambda: 0.05, start: 2024-02-11 17:55:05
# Run:  1, lambda: 0.10, start: 2024-02-11 17:55:30
# Run:  2, lambda: 0.15, start: 2024-02-11 17:55:40
# Run:  3, lambda: 0.20, start: 2024-02-11 17:55:47
# Run:  4, lambda: 0.25, start: 2024-02-11 17:55:53
# Run:  5, lambda: 0.30, start: 2024-02-11 17:55:58
# Run:  6, lambda: 0.35, start: 2024-02-11 17:56:02
# Run:  7, lambda: 0.40, start: 2024-02-11 17:56:06
# Run:  8, lambda: 0.45, start: 2024-02-11 17:56:10
# Run:  9, lambda: 0.50, start: 2024-02-11 17:56:13
# Run: 10, lambda: 0.55, start: 2024-02-11 17:56:16
# Run: 11, lambda: 0.60, start: 2024-02-11 17:56:18
# Run: 12, lambda: 0.65, start: 2024-02-11 17:56:21
# Run: 13, lambda: 0.70, start: 2024-02-11 17:56:24
# Run: 14, lambda: 0.75, start: 2024-02-11 17:56:26
# Run: 15, lambda: 0.80, start: 2024-02-11 17:56:28
# Run: 16, lambda: 0.85, start: 2024-02-11 17:56:31
# Run: 17, lambda: 0.90, start: 2024-02-11 17:56:34
# Run: 18, lambda: 0.95, start: 2024-02-11 17:56:37

# %%
r_squared_data = (
    pd.DataFrame(
        {
            "$R^2$ Test set": test_r_squared,
            "$R^2$ Training set": train_r_squared,
            "lambda": lambdas,
        }
    )
    .melt(id_vars=["lambda"])
)

r_squared_data["variable"] = r_squared_data["variable"].astype("category").cat.reorder_categories(
    ["$R^2$ Training set", "$R^2$ Test set"]
)

# %% [markdown]
# #### Comparing our training and tests sets, $R^{2}$ with our Lambdas

# %%
(
    ggplot(r_squared_data, aes(x="lambda", y="value", color="variable"))
    + geom_point()
    + geom_line(size=1, show_legend=False, na_rm=True)
    + scale_color_manual(name="", values=(color[1], color[0]))
    + scale_y_continuous(name="$R^2$")
    + theme_bw()
    + theme(subplots_adjust={"wspace": 0.25},legend_title=element_blank())
)
# Out:
# <Figure Size: (640 x 480)>

# %%
df_lam = pd.DataFrame(test_r_squared*100, columns=['R_squared'])
df_lam['lambda'] = (lambdas)
# returns the index of the row where column has maximum value.
df_lam.loc[df_lam['R_squared'].idxmax()]
# Out:
# R_squared    36.688152
# lambda        0.100000
# Name: 1, dtype: float64

# %%
reg_best = Lasso(alpha = df_lam.loc[df_lam['R_squared'].idxmax()]['lambda'])
reg_best.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
coefficients = reg_best.coef_[reg_best.coef_>0]

# Print the coefficients along with their corresponding feature names
for feature, coefficient in zip(model3.split('+'), coefficients):
    print(f"{feature.strip()}: {coefficient}")
# Out:
# ~f_property_type: 0.5453396373336897
# n_accommodates: 0.5884980716434304
# n_bedrooms: 0.4416571606270907
# n_bathrooms: 0.20139944432468748
# n_beds: 2.7101827313275537
# f_neighbourhood_cleansed: 1.0661951990617926
# n_number_of_reviews: 0.4963313966184026
# n_review_scores_rating: 1.53199025650803
# d_host_is_superhost: 0.21520634264353863
# d_instant_bookable: 4.674395907879571
# d_windowview: 0.8697080917970827
# d_pool: 0.32023820412844456
# d_luxuryamenities: 3.714322464714493
# d_gameconsole: 0.014810425641716068
# d_closet: 0.16608055004742667
# d_paidparking: 10.088826020699203
# d_gym: 0.006870789570147007
# d_smokingallowed: 2.352386588707063
# d_airconditioning: 0.24154694333497922
# d_soundsystem: 11.950607627446843
# d_coffeemaker: 5.335999849823754
# d_washer: 0.5261428802717903
# d_firstaidkit: 4.04338976150568
# d_conditioner: 0.05654498425041035
# d_privatelivingroom: 1.1392180127561085
# d_wifi: 7.854178673889184
# d_privateentrance: 8.67627154130685
# d_dryer: 1.5109791312169663
# d_bbq: 2.0954879097960215
# d_hairdryer: 1.838136477573951
# d_breakfast: 0.00020872268967096633
# d_essentials: 0.11794808546503385
# d_indoorfireplace: 2.3527378805415693
# d_tv: 0.3751512832444835
# d_elevator: 2.0792063666558795
# d_others: 0.05238899622106142
# d_hangers: 1.8221540995388985
# d_backyard: 0.8778279935763696
# d_hottub: 7.674629861990345
# d_dishwasher: 0.2025354096410574
# d_petfriendly: 0.12932648201833538
# d_freeparking: 0.11471834322547612
# d_fireextinguisher: 0.012354946527039968
# d_bodysoap: 0.6066327867540111
# d_refrigerator: 0.12532994937367753
# d_shampoo: 1.3732185978765514
# d_workspace: 0.9120175976823981
# d_kitchen: 0.3227869908675079
# d_cabletv: 0.4566377911673308
# d_kidfriendly: 3.542122198579878
# d_securitycameras: 0.41685270853449885
# d_selfcheckin: 0.6208702775201876
# d_lockbox: 0.2593696618011662
# d_smokedetector: 0.7497787780752033
# d_keypad: 0.873563699954705
# d_beachaccess: 0.17739296052028156
# d_outdooramenities: 0.17200849340298457
# f_property_type*d_host_is_superhost: 0.6529537695132628
# n_accommodates*d_host_is_superhost: 0.08760540109974695
# f_property_type*d_instant_bookable: 0.010283192227318959
# n_accommodates*d_instant_bookable: 1.2259338717148698
# f_property_type*d_windowview: 4.343845191234035
# n_accommodates*d_windowview: 0.10596876118516176
# f_property_type*d_pool: 1.2129596987656748
# n_accommodates*d_pool: 1.3163448799267365
# f_property_type*d_luxuryamenities: 1.1285471698448601
# n_accommodates*d_luxuryamenities: 1.3027644894091743
# f_property_type*d_gameconsole: 1.451411600183897
# n_accommodates*d_gameconsole: 2.683905406333535
# f_property_type*d_closet: 0.029395131958844082
# n_accommodates*d_closet: 0.8296474166415442
# f_property_type*d_paidparking: 1.553743751958785
# n_accommodates*d_paidparking: 0.44735501879580236
# f_property_type*d_gym: 5.819831351564642
# n_accommodates*d_gym: 0.742609559190991
# f_property_type*d_smokingallowed: 0.6712172683685719
# n_accommodates*d_smokingallowed: 1.110138774356419
# f_property_type*d_airconditioning: 0.33942883057440215
# n_accommodates*d_airconditioning: 0.01018519512764166
# f_property_type*d_soundsystem: 0.033160831074190995
# n_accommodates*d_soundsystem: 1.386241337950846
# f_property_type*d_coffeemaker: 0.8809520965132415
# n_accommodates*d_coffeemaker: 0.8910450563921826
# f_property_type*d_washer: 1.206046263141066
# n_accommodates*d_washer: 0.10491057451325314
# f_property_type*d_firstaidkit: 1.8773504754952979
# n_accommodates*d_firstaidkit: 0.8894503625688817
# f_property_type*d_conditioner: 0.41087231916048594
# n_accommodates*d_conditioner: 0.36201495560954694
# f_property_type*d_privatelivingroom: 1.4629802089120254
# n_accommodates*d_privatelivingroom: 0.34823243939635407
# f_property_type*d_wifi: 2.448412219294038
# n_accommodates*d_wifi: 0.1974712641713046
# f_property_type*d_privateentrance: 0.5049029312674546
# n_accommodates*d_privateentrance: 0.5837725075443703
# f_property_type*d_dryer: 0.9725497641632779
# n_accommodates*d_dryer: 1.258569300246931
# f_property_type*d_bbq: 0.49881528704311306
# n_accommodates*d_bbq: 0.7087475656611628
# f_property_type*d_hairdryer: 1.7776009446564698
# n_accommodates*d_hairdryer: 0.2648913244086846
# f_property_type*d_breakfast: 1.7871673219281352
# n_accommodates*d_breakfast: 0.26705985036367813
# f_property_type*d_essentials: 3.3847728475433865
# n_accommodates*d_essentials: 0.5706515759549248
# f_property_type*d_indoorfireplace: 2.7671296359063926
# n_accommodates*d_indoorfireplace: 1.5990348359307816
# f_property_type*d_tv: 1.7191418205113127
# n_accommodates*d_tv: 0.441466588487228
# f_property_type*d_elevator: 0.2786147288810229
# n_accommodates*d_elevator: 1.0313245362935963
# f_property_type*d_others: 2.060733759450724

# %%
coefficients_data = [
    (feature.strip(), coefficient) 
    for feature, coefficient in zip(model3.split('+'), coefficients)
]

coefficients_df = pd.DataFrame(coefficients_data, columns=['Feature', 'Coefficient'])

# %% [markdown]
# <b>*According to LASSO, 113 variables should be used (based on my given strictness value of 0)*

# %%
coefficients_df['Feature'] = coefficients_df['Feature'].str.replace('~','')
coefficients_df['Feature'] = coefficients_df['Feature'].str.replace(')','')
coefficients_df['Feature'] = coefficients_df['Feature'].str.replace('(','')
coefficients_df.shape
# Out:
# (112, 2)

# %%
coefficients_df
# Out:
#                                  Feature  Coefficient
# 0                        f_property_type     0.545340
# 1                         n_accommodates     0.588498
# 2                             n_bedrooms     0.441657
# 3                            n_bathrooms     0.201399
# 4                                 n_beds     2.710183
# 5               f_neighbourhood_cleansed     1.066195
# 6                    n_number_of_reviews     0.496331
# 7                 n_review_scores_rating     1.531990
# 8                    d_host_is_superhost     0.215206
# 9                     d_instant_bookable     4.674396
# 10                          d_windowview     0.869708
# 11                                d_pool     0.320238
# 12                     d_luxuryamenities     3.714322
# 13                         d_gameconsole     0.014810
# 14                              d_closet     0.166081
# 15                         d_paidparking    10.088826
# 16                                 d_gym     0.006871
# 17                      d_smokingallowed     2.352387
# 18                     d_airconditioning     0.241547
# 19                         d_soundsystem    11.950608
# 20                         d_coffeemaker     5.336000
# 21                              d_washer     0.526143
# 22                         d_firstaidkit     4.043390
# 23                         d_conditioner     0.056545
# 24                   d_privatelivingroom     1.139218
# 25                                d_wifi     7.854179
# 26                     d_privateentrance     8.676272
# 27                               d_dryer     1.510979
# 28                                 d_bbq     2.095488
# 29                           d_hairdryer     1.838136
# 30                           d_breakfast     0.000209
# 31                          d_essentials     0.117948
# 32                     d_indoorfireplace     2.352738
# 33                                  d_tv     0.375151
# 34                            d_elevator     2.079206
# 35                              d_others     0.052389
# 36                             d_hangers     1.822154
# 37                            d_backyard     0.877828
# 38                              d_hottub     7.674630
# 39                          d_dishwasher     0.202535
# 40                         d_petfriendly     0.129326
# 41                         d_freeparking     0.114718
# 42                    d_fireextinguisher     0.012355
# 43                            d_bodysoap     0.606633
# 44                        d_refrigerator     0.125330
# 45                             d_shampoo     1.373219
# 46                           d_workspace     0.912018
# 47                             d_kitchen     0.322787
# 48                             d_cabletv     0.456638
# 49                         d_kidfriendly     3.542122
# 50                     d_securitycameras     0.416853
# 51                         d_selfcheckin     0.620870
# 52                             d_lockbox     0.259370
# 53                       d_smokedetector     0.749779
# 54                              d_keypad     0.873564
# 55                         d_beachaccess     0.177393
# 56                    d_outdooramenities     0.172008
# 57   f_property_type*d_host_is_superhost     0.652954
# 58    n_accommodates*d_host_is_superhost     0.087605
# 59    f_property_type*d_instant_bookable     0.010283
# 60     n_accommodates*d_instant_bookable     1.225934
# 61          f_property_type*d_windowview     4.343845
# 62           n_accommodates*d_windowview     0.105969
# 63                f_property_type*d_pool     1.212960
# 64                 n_accommodates*d_pool     1.316345
# 65     f_property_type*d_luxuryamenities     1.128547
# 66      n_accommodates*d_luxuryamenities     1.302764
# 67         f_property_type*d_gameconsole     1.451412
# 68          n_accommodates*d_gameconsole     2.683905
# 69              f_property_type*d_closet     0.029395
# 70               n_accommodates*d_closet     0.829647
# 71         f_property_type*d_paidparking     1.553744
# 72          n_accommodates*d_paidparking     0.447355
# 73                 f_property_type*d_gym     5.819831
# 74                  n_accommodates*d_gym     0.742610
# 75      f_property_type*d_smokingallowed     0.671217
# 76       n_accommodates*d_smokingallowed     1.110139
# 77     f_property_type*d_airconditioning     0.339429
# 78      n_accommodates*d_airconditioning     0.010185
# 79         f_property_type*d_soundsystem     0.033161
# 80          n_accommodates*d_soundsystem     1.386241
# 81         f_property_type*d_coffeemaker     0.880952
# 82          n_accommodates*d_coffeemaker     0.891045
# 83              f_property_type*d_washer     1.206046
# 84               n_accommodates*d_washer     0.104911
# 85         f_property_type*d_firstaidkit     1.877350
# 86          n_accommodates*d_firstaidkit     0.889450
# 87         f_property_type*d_conditioner     0.410872
# 88          n_accommodates*d_conditioner     0.362015
# 89   f_property_type*d_privatelivingroom     1.462980
# 90    n_accommodates*d_privatelivingroom     0.348232
# 91                f_property_type*d_wifi     2.448412
# 92                 n_accommodates*d_wifi     0.197471
# 93     f_property_type*d_privateentrance     0.504903
# 94      n_accommodates*d_privateentrance     0.583773
# 95               f_property_type*d_dryer     0.972550
# 96                n_accommodates*d_dryer     1.258569
# 97                 f_property_type*d_bbq     0.498815
# 98                  n_accommodates*d_bbq     0.708748
# 99           f_property_type*d_hairdryer     1.777601
# 100           n_accommodates*d_hairdryer     0.264891
# 101          f_property_type*d_breakfast     1.787167
# 102           n_accommodates*d_breakfast     0.267060
# 103         f_property_type*d_essentials     3.384773
# 104          n_accommodates*d_essentials     0.570652
# 105    f_property_type*d_indoorfireplace     2.767130
# 106     n_accommodates*d_indoorfireplace     1.599035
# 107                 f_property_type*d_tv     1.719142
# 108                  n_accommodates*d_tv     0.441467
# 109           f_property_type*d_elevator     0.278615
# 110            n_accommodates*d_elevator     1.031325
# 111             f_property_type*d_others     2.060734

# %%
num_words = coefficients_df.shape[0]

print("Number of variables after LASSO: ", num_words)
# Out:
# Number of variables after LASSO:  112

# %%
def interactions(df, factor_var, dummy_var, factor_lab, dummy_lab):
    stats = df.groupby([factor_var, dummy_var]).agg(
        Mean=("price", np.mean), sd=("price", np.std), size=("price", "size")
    )
    stats["se"] = stats["sd"] / stats["size"] ** (1 / 2)
    stats["Mean_l"] = stats["Mean"] - (1.96 * stats["se"])
    stats["Mean_u"] = stats["Mean"] + (1.96 * stats["se"])
    stats = stats.drop(["sd", "size"], axis=1).reset_index()
    plot = (
        ggplot(
            stats,
            aes(
                stats.columns[0],
                stats.columns[2],
                fill="factor(" + stats.columns[1] + ")",
            ),
        )
        + geom_bar(stat="identity", position=position_dodge(width=0.9))
        + geom_errorbar(
            aes(ymin="Mean_l", ymax="Mean_u"),
            position=position_dodge(width=0.9),
            width=0.25,
        )
        + scale_color_manual(name=dummy_lab, values=("#A2A4A2", "#008080"))
        + scale_fill_manual(name=dummy_lab, values=("#A2A4A2", "#008080"))
        + ylab("Mean Price")
        + xlab(factor_lab)
        + theme_bw()
        + theme(
            panel_grid_major=element_blank(),
            panel_grid_minor=element_blank(),
            panel_border=element_blank(),
            axis_line=element_line(),
            legend_position="top",
            legend_box="vertical",
            legend_text=element_text(size=8),
            legend_title=element_text(size=8, face="bold"),
            figure_size=(8, 6)
        )
    )

    return plot

# %%
interactions(clean_df,"f_property_type","d_kidfriendly","Property Type","Kid Friendly")
# Out:
# <Figure Size: (800 x 600)>

# %%
interactions(clean_df,"f_property_type","d_freeparking","Property Type","Free Parking")
# Out:
# <Figure Size: (800 x 600)>

# %%
interactions(clean_df,"f_property_type","d_windowview","Property Type","Nice Window View")
# Out:
# <Figure Size: (800 x 600)>

# %%
interactions(clean_df,"f_property_type","d_outdooramenities","Property Type","Outdoor Amenities")
# Out:
# <Figure Size: (800 x 600)>

# %%
interactions(clean_df,"f_property_type","d_airconditioning","Property Type","Air Conditioning")
# Out:
# <Figure Size: (800 x 600)>

# %%
interactions(clean_df,"n_accommodates","d_airconditioning","Accommodates","Air Conditioning")
# Out:
# <Figure Size: (800 x 600)>

# %% [markdown]
# # Modelling
# 1. Random Forest
# 2. LASSO
# 3. OLS
# 4. CART
# 5. GBM

# %% [markdown]
# <b>*Splitting our data into train and test data with a split of 70/30*<br>

# %%
data_train, data_holdout = train_test_split(clean_df, train_size=0.7, random_state=42)
data_train.shape, data_holdout.shape
# Out:
# ((8220, 63), (3523, 63))

# %% [markdown]
# ## 1. Random Forest

# %%
y, X = dmatrices("price ~ " + " + ".join(predictors), data_train)

# %%
print('The theoretical recommended number of variables: {:.2f}.'.format(math.sqrt(len(X.design_info.column_names))))
# Out:
# The theoretical recommended number of variables: 13.19.

# %%
rfr = RandomForestRegressor(random_state=20240210)

# %%
# for the max_features, I have given a range of 10-16 (13 +- 3)

tune_grid = {"max_features": [10, 12, 14, 16], "min_samples_leaf": [5, 10, 15]}

# %%
rf_random = GridSearchCV(
    rfr,
    tune_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)

# %%
# %%time
rf_model = rf_random.fit(X, y.ravel())
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_features=10, min_samples_leaf=5;, score=-40.811 total time=   1.3s
# [CV 2/5] END max_features=10, min_samples_leaf=5;, score=-41.186 total time=   1.4s
# [CV 3/5] END max_features=10, min_samples_leaf=5;, score=-39.288 total time=   1.2s
# [CV 4/5] END max_features=10, min_samples_leaf=5;, score=-40.491 total time=   1.2s
# [CV 5/5] END max_features=10, min_samples_leaf=5;, score=-40.568 total time=   1.2s
# [CV 1/5] END max_features=10, min_samples_leaf=10;, score=-41.605 total time=   0.9s
# [CV 2/5] END max_features=10, min_samples_leaf=10;, score=-42.206 total time=   1.0s
# [CV 3/5] END max_features=10, min_samples_leaf=10;, score=-40.051 total time=   0.9s
# [CV 4/5] END max_features=10, min_samples_leaf=10;, score=-41.152 total time=   0.9s
# [CV 5/5] END max_features=10, min_samples_leaf=10;, score=-41.436 total time=   1.0s
# [CV 1/5] END max_features=10, min_samples_leaf=15;, score=-42.164 total time=   0.7s
# [CV 2/5] END max_features=10, min_samples_leaf=15;, score=-42.774 total time=   0.8s
# [CV 3/5] END max_features=10, min_samples_leaf=15;, score=-40.454 total time=   0.9s
# [CV 4/5] END max_features=10, min_samples_leaf=15;, score=-41.525 total time=   0.8s
# [CV 5/5] END max_features=10, min_samples_leaf=15;, score=-41.850 total time=   0.7s
# [CV 1/5] END max_features=12, min_samples_leaf=5;, score=-40.395 total time=   1.4s
# [CV 2/5] END max_features=12, min_samples_leaf=5;, score=-40.913 total time=   1.5s
# [CV 3/5] END max_features=12, min_samples_leaf=5;, score=-38.878 total time=   1.4s
# [CV 4/5] END max_features=12, min_samples_leaf=5;, score=-40.229 total time=   1.5s
# [CV 5/5] END max_features=12, min_samples_leaf=5;, score=-40.146 total time=   1.4s
# [CV 1/5] END max_features=12, min_samples_leaf=10;, score=-41.075 total time=   1.1s
# [CV 2/5] END max_features=12, min_samples_leaf=10;, score=-41.738 total time=   1.1s
# [CV 3/5] END max_features=12, min_samples_leaf=10;, score=-39.633 total time=   1.1s
# [CV 4/5] END max_features=12, min_samples_leaf=10;, score=-40.802 total time=   1.1s
# [CV 5/5] END max_features=12, min_samples_leaf=10;, score=-40.870 total time=   1.0s
# [CV 1/5] END max_features=12, min_samples_leaf=15;, score=-41.581 total time=   1.0s
# [CV 2/5] END max_features=12, min_samples_leaf=15;, score=-42.278 total time=   1.0s
# [CV 3/5] END max_features=12, min_samples_leaf=15;, score=-40.011 total time=   0.9s
# [CV 4/5] END max_features=12, min_samples_leaf=15;, score=-41.179 total time=   1.0s
# [CV 5/5] END max_features=12, min_samples_leaf=15;, score=-41.412 total time=   1.0s
# [CV 1/5] END max_features=14, min_samples_leaf=5;, score=-40.018 total time=   1.7s
# [CV 2/5] END max_features=14, min_samples_leaf=5;, score=-40.580 total time=   1.6s
# [CV 3/5] END max_features=14, min_samples_leaf=5;, score=-38.582 total time=   1.5s
# [CV 4/5] END max_features=14, min_samples_leaf=5;, score=-40.020 total time=   1.7s
# [CV 5/5] END max_features=14, min_samples_leaf=5;, score=-39.977 total time=   1.6s
# [CV 1/5] END max_features=14, min_samples_leaf=10;, score=-40.826 total time=   1.2s
# [CV 2/5] END max_features=14, min_samples_leaf=10;, score=-41.458 total time=   1.2s
# [CV 3/5] END max_features=14, min_samples_leaf=10;, score=-39.322 total time=   1.3s
# [CV 4/5] END max_features=14, min_samples_leaf=10;, score=-40.536 total time=   1.2s
# [CV 5/5] END max_features=14, min_samples_leaf=10;, score=-40.509 total time=   1.2s
# [CV 1/5] END max_features=14, min_samples_leaf=15;, score=-41.235 total time=   1.0s
# [CV 2/5] END max_features=14, min_samples_leaf=15;, score=-41.864 total time=   0.9s
# [CV 3/5] END max_features=14, min_samples_leaf=15;, score=-39.801 total time=   1.0s
# [CV 4/5] END max_features=14, min_samples_leaf=15;, score=-40.949 total time=   0.9s
# [CV 5/5] END max_features=14, min_samples_leaf=15;, score=-41.073 total time=   0.9s
# [CV 1/5] END max_features=16, min_samples_leaf=5;, score=-39.927 total time=   1.7s
# [CV 2/5] END max_features=16, min_samples_leaf=5;, score=-40.442 total time=   1.8s
# [CV 3/5] END max_features=16, min_samples_leaf=5;, score=-38.380 total time=   1.8s
# [CV 4/5] END max_features=16, min_samples_leaf=5;, score=-39.840 total time=   1.7s
# [CV 5/5] END max_features=16, min_samples_leaf=5;, score=-39.658 total time=   1.9s
# [CV 1/5] END max_features=16, min_samples_leaf=10;, score=-40.581 total time=   1.6s
# [CV 2/5] END max_features=16, min_samples_leaf=10;, score=-41.145 total time=   1.3s
# [CV 3/5] END max_features=16, min_samples_leaf=10;, score=-39.006 total time=   1.4s
# [CV 4/5] END max_features=16, min_samples_leaf=10;, score=-40.500 total time=   1.4s
# [CV 5/5] END max_features=16, min_samples_leaf=10;, score=-40.428 total time=   1.5s
# [CV 1/5] END max_features=16, min_samples_leaf=15;, score=-41.031 total time=   1.2s
# [CV 2/5] END max_features=16, min_samples_leaf=15;, score=-41.679 total time=   1.1s
# [CV 3/5] END max_features=16, min_samples_leaf=15;, score=-39.512 total time=   1.6s
# [CV 4/5] END max_features=16, min_samples_leaf=15;, score=-40.767 total time=   1.3s
# [CV 5/5] END max_features=16, min_samples_leaf=15;, score=-40.909 total time=   1.2s
# CPU times: total: 52.8 s
# Wall time: 1min 22s

# %%
df_rf_model_cv_results = pd.DataFrame(rf_model.cv_results_)[[
    'param_max_features', 'param_min_samples_leaf', 'mean_test_score']]

# %%
df_rf_model_cv_results.columns = ['max features', 'min node size', 'RMSE']

# %%
df_rf_model_cv_results
# Out:
#    max features min node size       RMSE
# 0            10             5 -40.468781
# 1            10            10 -41.289954
# 2            10            15 -41.753449
# 3            12             5 -40.112092
# 4            12            10 -40.823722
# 5            12            15 -41.292108
# 6            14             5 -39.835402
# 7            14            10 -40.529927
# 8            14            15 -40.984278
# 9            16             5 -39.649428
# 10           16            10 -40.331971
# 11           16            15 -40.779560

# %%
df_rf_model_cv_results.pivot(
    index = 'max features', 
    columns = 'min node size', 
    values = 'RMSE').round(2)*-1
# Out:
# min node size     5      10     15
# max features
# 10             40.47  41.29  41.75
# 12             40.11  40.82  41.29
# 14             39.84  40.53  40.98
# 16             39.65  40.33  40.78

# %%
rf_rmse = rf_model.best_score_*-1
rf_rmse.round(3)
# Out:
# 39.649

# %%
rf_model.best_params_
# Out:
# {'max_features': 16, 'min_samples_leaf': 5}

# %%
rf_model.best_estimator_
# Out:
# RandomForestRegressor(max_features=16, min_samples_leaf=5,
#                       random_state=20240210)

# %% [markdown]
# ## 2. LASSO

# %%
lasso_model =  ElasticNet(l1_ratio = 1, fit_intercept = True)

# %%
lasso_model_cv = GridSearchCV(
    lasso_model,
    {"alpha":[i/100 for i in range(5, 26, 5)]},
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)

# %%
y, X = dmatrices("price ~ " + " + ".join(coefficients_df['Feature']), data_train)

# %%
# %%time
lasso_model_cv.fit(X, y.ravel())
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END ......................alpha=0.05;, score=-38.873 total time=   0.6s
# [CV 2/5] END ......................alpha=0.05;, score=-39.043 total time=   0.4s
# [CV 3/5] END ......................alpha=0.05;, score=-37.287 total time=   0.6s
# [CV 4/5] END ......................alpha=0.05;, score=-39.467 total time=   0.5s
# [CV 5/5] END ......................alpha=0.05;, score=-39.076 total time=   0.5s
# [CV 1/5] END .......................alpha=0.1;, score=-38.901 total time=   0.2s
# [CV 2/5] END .......................alpha=0.1;, score=-39.251 total time=   0.3s
# [CV 3/5] END .......................alpha=0.1;, score=-37.428 total time=   0.4s
# [CV 4/5] END .......................alpha=0.1;, score=-39.645 total time=   0.3s
# [CV 5/5] END .......................alpha=0.1;, score=-39.285 total time=   0.2s
# [CV 1/5] END ......................alpha=0.15;, score=-38.944 total time=   0.1s
# [CV 2/5] END ......................alpha=0.15;, score=-39.423 total time=   0.1s
# [CV 3/5] END ......................alpha=0.15;, score=-37.593 total time=   0.2s
# [CV 4/5] END ......................alpha=0.15;, score=-39.776 total time=   0.2s
# [CV 5/5] END ......................alpha=0.15;, score=-39.505 total time=   0.1s
# [CV 1/5] END .......................alpha=0.2;, score=-39.087 total time=   0.1s
# [CV 2/5] END .......................alpha=0.2;, score=-39.634 total time=   0.1s
# [CV 3/5] END .......................alpha=0.2;, score=-37.808 total time=   0.2s
# [CV 4/5] END .......................alpha=0.2;, score=-39.943 total time=   0.2s
# [CV 5/5] END .......................alpha=0.2;, score=-39.696 total time=   0.1s
# [CV 1/5] END ......................alpha=0.25;, score=-39.240 total time=   0.1s
# [CV 2/5] END ......................alpha=0.25;, score=-39.828 total time=   0.1s
# [CV 3/5] END ......................alpha=0.25;, score=-38.030 total time=   0.2s
# [CV 4/5] END ......................alpha=0.25;, score=-40.131 total time=   0.2s
# [CV 5/5] END ......................alpha=0.25;, score=-39.880 total time=   0.1s
# CPU times: total: 18.7 s
# Wall time: 9.38 s
# GridSearchCV(cv=5, estimator=ElasticNet(l1_ratio=1),
#              param_grid={'alpha': [0.05, 0.1, 0.15, 0.2, 0.25]},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
pd.DataFrame(
    lasso_model_cv.best_estimator_.coef_.tolist(),
    index=X.design_info.column_names,
    columns=["lasso_coefficient"],
).assign(lasso_coefficient=lambda x: x.lasso_coefficient.round(3)).loc[
    lambda x: x.lasso_coefficient != 0
]
# Out:
#                                                     lasso_coefficient
# f_neighbourhood_cleansed[T.Ajuda]                              -0.819
# f_neighbourhood_cleansed[T.Alcntara]                            2.862
# f_neighbourhood_cleansed[T.Arroios]                            11.609
# f_neighbourhood_cleansed[T.Avenidas Novas]                      4.524
# f_neighbourhood_cleansed[T.Belm]                                0.067
# f_neighbourhood_cleansed[T.Campo de Ourique]                   11.163
# f_neighbourhood_cleansed[T.Cascais e Estoril]                  22.803
# f_neighbourhood_cleansed[T.Colares]                             8.754
# f_neighbourhood_cleansed[T.Ericeira]                            2.488
# f_neighbourhood_cleansed[T.Estrela]                            15.025
# f_neighbourhood_cleansed[T.Lourinh e Atalaia]                 -13.186
# f_neighbourhood_cleansed[T.Misericrdia]                        28.587
# f_neighbourhood_cleansed[T.Parque das Naes]                    17.294
# f_neighbourhood_cleansed[T.S.Maria, S.Miguel, S...              2.039
# f_neighbourhood_cleansed[T.Santa Brbara]                       -0.713
# f_neighbourhood_cleansed[T.Santa Maria Maior]                  31.077
# f_neighbourhood_cleansed[T.Santo Antnio]                       23.371
# f_neighbourhood_cleansed[T.Silveira]                           -7.950
# f_neighbourhood_cleansed[T.So Joo das Lampas e ...             -2.083
# f_neighbourhood_cleansed[T.So Vicente]                         16.326
# n_accommodates                                                  1.015
# n_bedrooms                                                     11.221
# n_bathrooms                                                    18.211
# n_beds                                                          0.465
# n_number_of_reviews                                            -0.051
# n_review_scores_rating                                          3.480
# f_property_type[T.Apartment]:d_host_is_superhost                1.674
# d_instant_bookable                                              1.723
# f_property_type[T.Apartment]:d_instant_bookable                 3.252
# d_windowview                                                    7.274
# f_property_type[T.Loft]:d_windowview                            2.339
# d_pool                                                         26.760
# d_luxuryamenities                                               0.377
# f_property_type[T.Apartment]:d_luxuryamenities                  1.055
# d_closet                                                        2.062
# f_property_type[T.Apartment]:d_closet                          -0.457
# d_paidparking                                                  -4.566
# f_property_type[T.Condo]:d_paidparking                          3.655
# f_property_type[T.Apartment]:d_paidparking                     -2.017
# f_property_type[T.Apartment]:d_gym                             -4.390
# f_property_type[T.Condo]:d_smokingallowed                       0.353
# d_airconditioning                                               8.366
# f_property_type[T.Condo]:d_airconditioning                     -0.208
# f_property_type[T.Apartment]:d_airconditioning                  1.406
# d_soundsystem                                                   3.431
# f_property_type[T.Apartment]:d_soundsystem                      2.541
# d_washer                                                        3.796
# d_firstaidkit                                                  -7.715
# f_property_type[T.Apartment]:d_privatelivingroom                0.369
# f_property_type[T.Apartment]:d_wifi                            -3.435
# f_property_type[T.Condo]:d_privateentrance                     -4.268
# d_dryer                                                         9.178
# f_property_type[T.Apartment]:d_dryer                           -2.823
# f_property_type[T.Apartment]:d_breakfast                        9.086
# d_indoorfireplace                                               4.110
# f_property_type[T.Apartment]:d_indoorfireplace                 -3.776
# f_property_type[T.Loft]:d_indoorfireplace                       3.626
# d_tv                                                            2.747
# f_property_type[T.Condo]:d_tv                                   1.619
# f_property_type[T.Apartment]:d_tv                               1.642
# f_property_type[T.Apartment]:d_elevator                        12.152
# d_others                                                       -1.235
# d_hangers                                                      -9.316
# d_backyard                                                      3.188
# d_hottub                                                        5.652
# d_dishwasher                                                   10.111
# d_petfriendly                                                  -2.807
# d_freeparking                                                  -7.831
# d_fireextinguisher                                              4.120
# d_bodysoap                                                      4.133
# d_refrigerator                                                 -7.762
# d_shampoo                                                       2.999
# d_workspace                                                    -0.377
# d_cabletv                                                       4.367
# d_kidfriendly                                                   3.182
# d_securitycameras                                               5.543
# d_selfcheckin                                                   3.225
# d_lockbox                                                      -2.658
# d_smokedetector                                                 6.400
# d_keypad                                                        3.755
# d_beachaccess                                                   2.385
# d_outdooramenities                                              2.857
# n_accommodates:d_host_is_superhost                              1.189
# n_accommodates:d_instant_bookable                               1.094
# n_accommodates:d_windowview                                    -0.433
# n_accommodates:d_pool                                          -1.816
# n_accommodates:d_luxuryamenities                               -0.941
# n_accommodates:d_gameconsole                                   -0.146
# n_accommodates:d_closet                                        -0.343
# n_accommodates:d_paidparking                                    2.042
# n_accommodates:d_gym                                            1.611
# n_accommodates:d_smokingallowed                                -1.814
# n_accommodates:d_airconditioning                               -0.152
# n_accommodates:d_coffeemaker                                   -0.154
# n_accommodates:d_washer                                        -1.150
# n_accommodates:d_firstaidkit                                    1.529
# n_accommodates:d_conditioner                                   -0.150
# n_accommodates:d_privatelivingroom                              0.152
# n_accommodates:d_wifi                                           3.048
# n_accommodates:d_privateentrance                                0.346
# n_accommodates:d_bbq                                           -0.764
# n_accommodates:d_essentials                                    -0.579
# n_accommodates:d_indoorfireplace                               -0.830
# n_accommodates:d_tv                                             1.045
# n_accommodates:d_elevator                                      -0.383

# %%
lasso_model_cv.best_estimator_
# Out:
# ElasticNet(alpha=0.05, l1_ratio=1)

# %%
lasso_model_cv.cv_results_
# Out:
# {'mean_fit_time': array([0.62635784, 0.38545885, 0.25557718, 0.24319878, 0.24086452]),
#  'std_fit_time': array([0.06216433, 0.0654196 , 0.04058342, 0.02381378, 0.02605057]),
#  'mean_score_time': array([0.00341711, 0.00311689, 0.00321655, 0.00290918, 0.00248532]),
#  'std_score_time': array([0.00038074, 0.00057719, 0.00082219, 0.00049318, 0.00047961]),
#  'param_alpha': masked_array(data=[0.05, 0.1, 0.15, 0.2, 0.25],
#               mask=[False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.05},
#   {'alpha': 0.1},
#   {'alpha': 0.15},
#   {'alpha': 0.2},
#   {'alpha': 0.25}],
#  'split0_test_score': array([-38.87281305, -38.90116786, -38.9442608 , -39.08672897,
#         -39.23979853]),
#  'split1_test_score': array([-39.0427896 , -39.25052342, -39.42342232, -39.63396773,
#         -39.82771748]),
#  'split2_test_score': array([-37.28749359, -37.4276773 , -37.59252181, -37.80846826,
#         -38.03011156]),
#  'split3_test_score': array([-39.46745334, -39.64485737, -39.77554097, -39.94265069,
#         -40.13091551]),
#  'split4_test_score': array([-39.07551153, -39.28520483, -39.50490762, -39.69646643,
#         -39.8800879 ]),
#  'mean_test_score': array([-38.74921222, -38.90188615, -39.0481307 , -39.23365642,
#         -39.42172619]),
#  'std_test_score': array([0.75636337, 0.77379321, 0.77565467, 0.76548862, 0.75466056]),
#  'rank_test_score': array([1, 2, 3, 4, 5])}

# %%
lasso_rmse = pd.DataFrame(lasso_model_cv.cv_results_).loc[
    lambda x: x.param_alpha == lasso_model_cv.best_estimator_.alpha
].mean_test_score.values[0] * -1
lasso_rmse
# Out:
# 38.749212221683

# %% [markdown]
# ## 3. OLS

# %%
y, X = dmatrices("price ~ " + " + ".join(coefficients_df['Feature']), data_train)

ols_model = LinearRegression().fit(X,y)

#y_test, X_test = dmatrices("price ~ " + " + ".join(predictors_2), data_holdout)

y_hat = ols_model.predict(X)

ols_rmse = mean_squared_error(y,y_hat,squared=False)
ols_rmse
# Out:
# 37.447721818547045

# %%
ols_model_coeffs_df = pd.DataFrame(
    ols_model.coef_.tolist()[0],
    index=X.design_info.column_names,
    columns=["ols_coefficient"],
).assign(ols_coefficient=lambda x: x.ols_coefficient.round(3))

# %%
ols_model_coeffs_df
# Out:
#                                                     ols_coefficient
# Intercept                                              6.246872e+05
# f_property_type[T.Condo]                              -1.410000e+00
# f_property_type[T.Apartment]                          -2.150000e-01
# f_property_type[T.Loft]                               -1.770500e+01
# f_neighbourhood_cleansed[T.Abrigada e Cabanas d...     5.812589e+11
# f_neighbourhood_cleansed[T.Agualva e Mira-Sintra]     -7.307000e+00
# f_neighbourhood_cleansed[T.Ajuda]                      1.063600e+01
# f_neighbourhood_cleansed[T.Alcabideche]                1.628000e+01
# f_neighbourhood_cleansed[T.Alcntara]                   2.286000e+01
# f_neighbourhood_cleansed[T.Aldeia Galega da Mer...    -3.069600e+01
# f_neighbourhood_cleansed[T.Alenquer (Santo Estv...     4.530100e+01
# f_neighbourhood_cleansed[T.Alfragide]                 -5.120000e+00
# f_neighbourhood_cleansed[T.Algs, Linda-a-Velha ...     1.237200e+01
# f_neighbourhood_cleansed[T.Alguber]                    3.946612e+10
# f_neighbourhood_cleansed[T.Algueiro-Mem Martins]      -9.931000e+00
# f_neighbourhood_cleansed[T.Alhandra, So Joo dos...     4.821300e+01
# f_neighbourhood_cleansed[T.Almargem do Bispo, P...    -1.630500e+01
# f_neighbourhood_cleansed[T.Alvalade]                   2.049500e+01
# f_neighbourhood_cleansed[T.Alverca do Ribatejo ...    -6.720400e+01
# f_neighbourhood_cleansed[T.Areeiro]                    1.478300e+01
# f_neighbourhood_cleansed[T.Arranh]                     4.390600e+01
# f_neighbourhood_cleansed[T.Arroios]                    2.979300e+01
# f_neighbourhood_cleansed[T.Arruda dos Vinhos]         -7.402597e+09
# f_neighbourhood_cleansed[T.Aveiras de Baixo]           1.017419e+10
# f_neighbourhood_cleansed[T.Avenidas Novas]             2.504500e+01
# f_neighbourhood_cleansed[T.Azambuja]                  -9.149000e+00
# f_neighbourhood_cleansed[T.Azueira e Sobral da ...    -5.478000e+00
# f_neighbourhood_cleansed[T.Barcarena]                 -1.761800e+01
# f_neighbourhood_cleansed[T.Beato]                      1.508400e+01
# f_neighbourhood_cleansed[T.Belm]                       1.836600e+01
# f_neighbourhood_cleansed[T.Benfica]                    8.050000e-01
# f_neighbourhood_cleansed[T.Bucelas]                   -5.769000e+00
# f_neighbourhood_cleansed[T.Cacm e So Marcos]           1.329200e+01
# f_neighbourhood_cleansed[T.Cadaval e Pro Moniz]       -3.516500e+01
# f_neighbourhood_cleansed[T.Camarate, Unhos e Ap...    -4.727100e+01
# f_neighbourhood_cleansed[T.Campelos e Outeiro d...    -2.551000e+01
# f_neighbourhood_cleansed[T.Campo de Ourique]           3.114000e+01
# f_neighbourhood_cleansed[T.Campolide]                  2.144000e+01
# f_neighbourhood_cleansed[T.Carcavelos e Parede]        1.552700e+01
# f_neighbourhood_cleansed[T.Carnaxide e Queijas]       -1.590200e+01
# f_neighbourhood_cleansed[T.Carnide]                    2.261300e+01
# f_neighbourhood_cleansed[T.Carregado e Cadafais]      -2.036944e+09
# f_neighbourhood_cleansed[T.Carvoeira]                  3.748000e+00
# f_neighbourhood_cleansed[T.Cascais e Estoril]          3.779600e+01
# f_neighbourhood_cleansed[T.Colares]                    1.945100e+01
# f_neighbourhood_cleansed[T.Dois Portos e Runa]        -2.098000e+00
# f_neighbourhood_cleansed[T.Encarnao]                   7.261000e+00
# f_neighbourhood_cleansed[T.Encosta do Sol]             1.971700e+01
# f_neighbourhood_cleansed[T.Enxara do Bispo, Gra...     1.901600e+01
# f_neighbourhood_cleansed[T.Ericeira]                   1.607800e+01
# f_neighbourhood_cleansed[T.Estrela]                    3.347600e+01
# f_neighbourhood_cleansed[T.Falagueira-Venda Nova]      5.138000e+00
# f_neighbourhood_cleansed[T.Freiria]                    5.033000e+00
# f_neighbourhood_cleansed[T.Igreja Nova e Chelei...     1.659800e+01
# f_neighbourhood_cleansed[T.Lamas e Cercal]            -3.691800e+01
# f_neighbourhood_cleansed[T.Loures]                    -2.594000e+01
# f_neighbourhood_cleansed[T.Lourinh e Atalaia]         -9.152000e+00
# f_neighbourhood_cleansed[T.Lousa]                     -2.257200e+01
# f_neighbourhood_cleansed[T.Lumiar]                     5.988000e+00
# f_neighbourhood_cleansed[T.Mafra]                     -2.230000e+00
# f_neighbourhood_cleansed[T.Manique do Intendent...    -1.906359e+09
# f_neighbourhood_cleansed[T.Marvila]                    1.892500e+01
# f_neighbourhood_cleansed[T.Massam e Monte Abrao]       9.068000e+00
# f_neighbourhood_cleansed[T.Maxial e Monte Redondo]    -3.738300e+01
# f_neighbourhood_cleansed[T.Meca]                      -1.089800e+01
# f_neighbourhood_cleansed[T.Mina de gua]                4.347000e+00
# f_neighbourhood_cleansed[T.Miragaia e Marteleira]     -2.900400e+01
# f_neighbourhood_cleansed[T.Misericrdia]                4.663700e+01
# f_neighbourhood_cleansed[T.Moscavide e Portela]        1.917400e+01
# f_neighbourhood_cleansed[T.Odivelas]                   2.879000e+00
# f_neighbourhood_cleansed[T.Oeiras e S.Julio da ...     9.842000e+00
# f_neighbourhood_cleansed[T.Olhalvo]                    7.325200e+01
# f_neighbourhood_cleansed[T.Olivais]                    1.394700e+01
# f_neighbourhood_cleansed[T.Parque das Naes]            3.668400e+01
# f_neighbourhood_cleansed[T.Penha de Frana]             1.755300e+01
# f_neighbourhood_cleansed[T.Peral]                     -4.117400e+01
# f_neighbourhood_cleansed[T.Ponte do Rol]              -3.303900e+01
# f_neighbourhood_cleansed[T.Pontinha e Fames]           8.890000e+00
# f_neighbourhood_cleansed[T.Porto Salvo]               -6.110600e+01
# f_neighbourhood_cleansed[T.Pvoa de Santa Iria e...    -1.762600e+01
# f_neighbourhood_cleansed[T.Pvoa de Santo Adrio ...     2.347000e+00
# f_neighbourhood_cleansed[T.Queluz e Belas]             1.716300e+01
# f_neighbourhood_cleansed[T.Ramada e Caneas]            1.434000e+00
# f_neighbourhood_cleansed[T.Reguengo Grande]           -6.070000e+00
# f_neighbourhood_cleansed[T.Ribafria e Pereiro d...    -7.396900e+01
# f_neighbourhood_cleansed[T.Ribamar]                   -7.144000e+00
# f_neighbourhood_cleansed[T.Rio de Mouro]              -1.405300e+01
# f_neighbourhood_cleansed[T.S.Maria, S.Miguel, S...     1.539600e+01
# f_neighbourhood_cleansed[T.S.Pedro e Santiago, ...    -7.300000e+00
# f_neighbourhood_cleansed[T.Sacavm e Prior Velho]       4.680000e-01
# f_neighbourhood_cleansed[T.Santa Brbara]              -3.071500e+01
# f_neighbourhood_cleansed[T.Santa Clara]               -1.592100e+01
# f_neighbourhood_cleansed[T.Santa Iria de Azoia,...    -7.790000e+00
# f_neighbourhood_cleansed[T.Santa Maria Maior]          4.905800e+01
# f_neighbourhood_cleansed[T.Santiago dos Velhos]       -1.000400e+01
# f_neighbourhood_cleansed[T.Santo Antnio]               4.130500e+01
# f_neighbourhood_cleansed[T.Santo Antnio dos Cav...    -5.246000e+00
# f_neighbourhood_cleansed[T.Santo Isidoro]              1.317300e+01
# f_neighbourhood_cleansed[T.Santo Quintino]            -2.382000e+00
# f_neighbourhood_cleansed[T.Sapataria]                 -1.994800e+01
# f_neighbourhood_cleansed[T.Silveira]                  -9.055000e+00
# f_neighbourhood_cleansed[T.So Bartolomeu dos Ga...    -3.782900e+01
# f_neighbourhood_cleansed[T.So Domingos de Benfica]     2.063400e+01
# f_neighbourhood_cleansed[T.So Domingos de Rana]        4.882000e+00
# f_neighbourhood_cleansed[T.So Joo das Lampas e ...    -3.421000e+00
# f_neighbourhood_cleansed[T.So Pedro da Cadeira]       -2.555000e+00
# f_neighbourhood_cleansed[T.So Vicente]                 3.399700e+01
# f_neighbourhood_cleansed[T.Sobral de Monte Agrao]     -9.902780e+07
# f_neighbourhood_cleansed[T.Turcifal]                  -7.968000e+00
# f_neighbourhood_cleansed[T.Vale do Paraso]            -6.690309e+06
# f_neighbourhood_cleansed[T.Venda do Pinheiro e ...    -4.303700e+01
# f_neighbourhood_cleansed[T.Venteira]                   8.595000e+00
# f_neighbourhood_cleansed[T.Ventosa]                    2.040000e-01
# f_neighbourhood_cleansed[T.Vialonga]                  -1.280700e+01
# f_neighbourhood_cleansed[T.Vila Franca de Xira]       -2.823200e+01
# f_neighbourhood_cleansed[T.Vila Verde dos Francos]    -3.549700e+01
# f_neighbourhood_cleansed[T.Vilar]                     -3.941300e+01
# f_neighbourhood_cleansed[T.Vimeiro]                   -2.491500e+01
# f_neighbourhood_cleansed[T.guas Livres]                1.632900e+01
# n_accommodates                                         2.089000e+00
# n_bedrooms                                             1.149800e+01
# n_bathrooms                                            1.787600e+01
# n_beds                                                 5.580000e-01
# n_number_of_reviews                                   -5.400000e-02
# n_review_scores_rating                                 4.309000e+00
# d_host_is_superhost                                   -1.495000e+00
# f_property_type[T.Condo]:d_host_is_superhost           4.194000e+00
# f_property_type[T.Apartment]:d_host_is_superhost       4.034000e+00
# f_property_type[T.Loft]:d_host_is_superhost           -1.016000e+00
# d_instant_bookable                                     4.601000e+00
# f_property_type[T.Condo]:d_instant_bookable            7.490000e-01
# f_property_type[T.Apartment]:d_instant_bookable        3.726000e+00
# f_property_type[T.Loft]:d_instant_bookable            -4.910000e-01
# d_windowview                                           1.041100e+01
# f_property_type[T.Condo]:d_windowview                 -5.508000e+00
# f_property_type[T.Apartment]:d_windowview             -3.287000e+00
# f_property_type[T.Loft]:d_windowview                   9.664000e+00
# d_pool                                                 4.873300e+01
# f_property_type[T.Condo]:d_pool                       -1.770600e+01
# f_property_type[T.Apartment]:d_pool                   -1.437100e+01
# f_property_type[T.Loft]:d_pool                         9.800000e-02
# d_luxuryamenities                                      2.820000e-01
# f_property_type[T.Condo]:d_luxuryamenities             2.252000e+00
# f_property_type[T.Apartment]:d_luxuryamenities         1.826000e+00
# f_property_type[T.Loft]:d_luxuryamenities             -1.444300e+01
# d_gameconsole                                         -8.248000e+00
# f_property_type[T.Condo]:d_gameconsole                 1.050100e+01
# f_property_type[T.Apartment]:d_gameconsole            -2.288000e+00
# f_property_type[T.Loft]:d_gameconsole                 -1.837300e+01
# d_closet                                               1.097600e+01
# f_property_type[T.Condo]:d_closet                     -8.040000e-01
# f_property_type[T.Apartment]:d_closet                 -6.146000e+00
# f_property_type[T.Loft]:d_closet                      -1.780000e-01
# d_paidparking                                         -9.007000e+00
# f_property_type[T.Condo]:d_paidparking                 8.060000e+00
# f_property_type[T.Apartment]:d_paidparking            -1.630000e-01
# f_property_type[T.Loft]:d_paidparking                 -9.502000e+00
# d_gym                                                 -1.180000e-01
# f_property_type[T.Condo]:d_gym                         7.543000e+00
# f_property_type[T.Apartment]:d_gym                    -1.217300e+01
# f_property_type[T.Loft]:d_gym                          5.480000e+00
# d_smokingallowed                                       7.472000e+00
# f_property_type[T.Condo]:d_smokingallowed              1.107500e+01
# f_property_type[T.Apartment]:d_smokingallowed         -5.193000e+00
# f_property_type[T.Loft]:d_smokingallowed              -1.400900e+01
# d_airconditioning                                      9.669000e+00
# f_property_type[T.Condo]:d_airconditioning            -4.630000e-01
# f_property_type[T.Apartment]:d_airconditioning         1.741000e+00
# f_property_type[T.Loft]:d_airconditioning              2.384000e+00
# d_soundsystem                                          4.820000e+00
# f_property_type[T.Condo]:d_soundsystem                 1.692400e+01
# f_property_type[T.Apartment]:d_soundsystem             1.470500e+01
# f_property_type[T.Loft]:d_soundsystem                  1.876300e+01
# d_coffeemaker                                          7.443000e+00
# f_property_type[T.Condo]:d_coffeemaker                -7.451000e+00
# f_property_type[T.Apartment]:d_coffeemaker            -4.544000e+00
# f_property_type[T.Loft]:d_coffeemaker                 -2.267000e+00
# d_washer                                               4.792000e+00
# f_property_type[T.Condo]:d_washer                      1.473000e+00
# f_property_type[T.Apartment]:d_washer                 -1.080000e-01
# f_property_type[T.Loft]:d_washer                      -2.323000e+00
# d_firstaidkit                                         -1.617700e+01
# f_property_type[T.Condo]:d_firstaidkit                 1.139200e+01
# f_property_type[T.Apartment]:d_firstaidkit             3.485000e+00
# f_property_type[T.Loft]:d_firstaidkit                 -2.103000e+00
# d_conditioner                                         -7.749000e+00
# f_property_type[T.Condo]:d_conditioner                 4.973000e+00
# f_property_type[T.Apartment]:d_conditioner             4.569000e+00
# f_property_type[T.Loft]:d_conditioner                 -1.824800e+01
# d_privatelivingroom                                   -8.669000e+00
# f_property_type[T.Condo]:d_privatelivingroom           2.497000e+00
# f_property_type[T.Apartment]:d_privatelivingroom       6.496000e+00
# f_property_type[T.Loft]:d_privatelivingroom            1.933200e+01
# d_wifi                                                 2.982000e+00
# f_property_type[T.Condo]:d_wifi                       -4.676000e+00
# f_property_type[T.Apartment]:d_wifi                   -1.048400e+01
# f_property_type[T.Loft]:d_wifi                         1.495000e+00
# d_privateentrance                                     -8.960000e-01
# f_property_type[T.Condo]:d_privateentrance            -1.067400e+01
# f_property_type[T.Apartment]:d_privateentrance        -1.081000e+00
# f_property_type[T.Loft]:d_privateentrance             -6.276000e+00
# d_dryer                                                1.273500e+01
# f_property_type[T.Condo]:d_dryer                      -8.120000e-01
# f_property_type[T.Apartment]:d_dryer                  -5.113000e+00
# f_property_type[T.Loft]:d_dryer                        6.578000e+00
# d_bbq                                                  9.430000e-01
# f_property_type[T.Condo]:d_bbq                         3.174000e+00
# f_property_type[T.Apartment]:d_bbq                    -1.000000e-02
# f_property_type[T.Loft]:d_bbq                         -6.820000e+00
# d_hairdryer                                            1.846000e+00
# f_property_type[T.Condo]:d_hairdryer                  -5.090000e+00
# f_property_type[T.Apartment]:d_hairdryer               1.467000e+00
# f_property_type[T.Loft]:d_hairdryer                   -5.627000e+00
# d_breakfast                                            1.051500e+01
# f_property_type[T.Condo]:d_breakfast                   5.682400e+01
# f_property_type[T.Apartment]:d_breakfast               4.027900e+01
# f_property_type[T.Loft]:d_breakfast                    3.067000e+00
# d_essentials                                          -9.165000e+00
# f_property_type[T.Condo]:d_essentials                  2.170000e+00
# f_property_type[T.Apartment]:d_essentials              4.610000e-01
# f_property_type[T.Loft]:d_essentials                   3.515600e+01
# d_indoorfireplace                                      2.000900e+01
# f_property_type[T.Condo]:d_indoorfireplace            -6.064000e+00
# f_property_type[T.Apartment]:d_indoorfireplace        -5.728000e+00
# f_property_type[T.Loft]:d_indoorfireplace              8.448000e+00
# d_tv                                                  -2.820000e-01
# f_property_type[T.Condo]:d_tv                          9.651000e+00
# f_property_type[T.Apartment]:d_tv                      6.829000e+00
# f_property_type[T.Loft]:d_tv                           1.272700e+01
# d_elevator                                             8.065000e+00
# f_property_type[T.Condo]:d_elevator                   -6.469000e+00
# f_property_type[T.Apartment]:d_elevator                6.509000e+00
# f_property_type[T.Loft]:d_elevator                    -1.805600e+01
# d_others                                              -3.842000e+00
# f_property_type[T.Condo]:d_others                     -3.800000e+00
# f_property_type[T.Apartment]:d_others                  2.691000e+00
# f_property_type[T.Loft]:d_others                      -7.132000e+00
# d_hangers                                             -9.364000e+00
# d_backyard                                             3.116000e+00
# d_hottub                                               9.092000e+00
# d_dishwasher                                           1.007900e+01
# d_petfriendly                                         -2.419000e+00
# d_freeparking                                         -5.521000e+00
# d_fireextinguisher                                     5.060000e+00
# d_bodysoap                                             4.581000e+00
# d_refrigerator                                        -7.914000e+00
# d_shampoo                                              3.445000e+00
# d_workspace                                           -9.000000e-01
# d_kitchen                                             -1.950000e-01
# d_cabletv                                              5.279000e+00
# d_kidfriendly                                          3.250000e+00
# d_securitycameras                                      7.178000e+00
# d_selfcheckin                                          3.662000e+00
# d_lockbox                                             -2.959000e+00
# d_smokedetector                                        6.499000e+00
# d_keypad                                               4.446000e+00
# d_beachaccess                                          3.895000e+00
# d_outdooramenities                                     3.257000e+00
# n_accommodates:d_host_is_superhost                     9.810000e-01
# n_accommodates:d_instant_bookable                      3.170000e-01
# n_accommodates:d_windowview                           -4.720000e-01
# n_accommodates:d_pool                                 -3.951000e+00
# n_accommodates:d_luxuryamenities                      -9.800000e-01
# n_accommodates:d_gameconsole                           1.820000e+00
# n_accommodates:d_closet                               -1.341000e+00
# n_accommodates:d_paidparking                           2.333000e+00
# n_accommodates:d_gym                                   2.509000e+00
# n_accommodates:d_smokingallowed                       -2.614000e+00
# n_accommodates:d_airconditioning                      -6.940000e-01
# n_accommodates:d_soundsystem                          -3.220000e+00
# n_accommodates:d_coffeemaker                          -1.047000e+00
# n_accommodates:d_washer                               -1.439000e+00
# n_accommodates:d_firstaidkit                           2.558000e+00
# n_accommodates:d_conditioner                           8.630000e-01
# n_accommodates:d_privatelivingroom                     9.030000e-01
# n_accommodates:d_wifi                                  2.535000e+00
# n_accommodates:d_privateentrance                       8.980000e-01
# n_accommodates:d_dryer                                -5.480000e-01
# n_accommodates:d_bbq                                  -5.240000e-01
# n_accommodates:d_hairdryer                            -7.610000e-01
# n_accommodates:d_breakfast                            -8.228000e+00
# n_accommodates:d_essentials                            1.287000e+00
# n_accommodates:d_indoorfireplace                      -3.762000e+00
# n_accommodates:d_tv                                    8.410000e-01
# n_accommodates:d_elevator                             -8.740000e-01

# %% [markdown]
# ## 4. CART

# %%
y, X = dmatrices("price ~ " + " + ".join(coefficients_df['Feature']), data_train)
cart_model = DecisionTreeRegressor(random_state=20240210)

# %%
path = cart_model.cost_complexity_pruning_path(X, y.ravel())
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.00000000e+00, 6.08272506e-05, 6.08272506e-05, ...,
#        3.05793870e+01, 8.42914682e+01, 2.91912794e+02])

# %%
ccp_aplhas_filtered = [x for x in ccp_alphas if x > 2]

# %%
# %%time

cart_model_cv = RandomizedSearchCV(
    cart_model,
    {"ccp_alpha":ccp_aplhas_filtered},
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=3,
)
cart_model_cv.fit(X,y.ravel())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .....ccp_alpha=2.079755945526692;, score=-44.154 total time=   0.9s
# [CV 2/5] END .....ccp_alpha=2.079755945526692;, score=-44.370 total time=   0.9s
# [CV 3/5] END .....ccp_alpha=2.079755945526692;, score=-43.319 total time=   0.8s
# [CV 4/5] END .....ccp_alpha=2.079755945526692;, score=-44.492 total time=   0.9s
# [CV 5/5] END .....ccp_alpha=2.079755945526692;, score=-43.167 total time=   0.9s
# [CV 1/5] END .....ccp_alpha=3.253923603359084;, score=-42.987 total time=   0.9s
# [CV 2/5] END .....ccp_alpha=3.253923603359084;, score=-43.339 total time=   0.9s
# [CV 3/5] END .....ccp_alpha=3.253923603359084;, score=-41.596 total time=   0.9s
# [CV 4/5] END .....ccp_alpha=3.253923603359084;, score=-43.271 total time=   0.9s
# [CV 5/5] END .....ccp_alpha=3.253923603359084;, score=-42.614 total time=   0.9s
# [CV 1/5] END ....ccp_alpha=2.0678335294814048;, score=-44.154 total time=   1.0s
# [CV 2/5] END ....ccp_alpha=2.0678335294814048;, score=-44.439 total time=   0.9s
# [CV 3/5] END ....ccp_alpha=2.0678335294814048;, score=-43.307 total time=   0.9s
# [CV 4/5] END ....ccp_alpha=2.0678335294814048;, score=-44.529 total time=   0.8s
# [CV 5/5] END ....ccp_alpha=2.0678335294814048;, score=-43.208 total time=   0.9s
# [CV 1/5] END ......ccp_alpha=5.16789792399549;, score=-42.596 total time=   1.0s
# [CV 2/5] END ......ccp_alpha=5.16789792399549;, score=-42.909 total time=   0.9s
# [CV 3/5] END ......ccp_alpha=5.16789792399549;, score=-41.206 total time=   0.8s
# [CV 4/5] END ......ccp_alpha=5.16789792399549;, score=-42.425 total time=   0.9s
# [CV 5/5] END ......ccp_alpha=5.16789792399549;, score=-43.152 total time=   1.0s
# [CV 1/5] END .....ccp_alpha=3.923788417365401;, score=-42.819 total time=   1.0s
# [CV 2/5] END .....ccp_alpha=3.923788417365401;, score=-43.260 total time=   0.9s
# [CV 3/5] END .....ccp_alpha=3.923788417365401;, score=-41.190 total time=   0.9s
# [CV 4/5] END .....ccp_alpha=3.923788417365401;, score=-43.082 total time=   0.9s
# [CV 5/5] END .....ccp_alpha=3.923788417365401;, score=-42.829 total time=   0.9s
# [CV 1/5] END ....ccp_alpha=2.4998291043911536;, score=-43.180 total time=   0.9s
# [CV 2/5] END ....ccp_alpha=2.4998291043911536;, score=-43.588 total time=   0.9s
# [CV 3/5] END ....ccp_alpha=2.4998291043911536;, score=-42.496 total time=   0.9s
# [CV 4/5] END ....ccp_alpha=2.4998291043911536;, score=-43.626 total time=   0.8s
# [CV 5/5] END ....ccp_alpha=2.4998291043911536;, score=-42.533 total time=   1.0s
# [CV 1/5] END ....ccp_alpha=3.7888688866176445;, score=-42.736 total time=   1.3s
# [CV 2/5] END ....ccp_alpha=3.7888688866176445;, score=-43.214 total time=   1.2s
# [CV 3/5] END ....ccp_alpha=3.7888688866176445;, score=-41.190 total time=   0.9s
# [CV 4/5] END ....ccp_alpha=3.7888688866176445;, score=-43.111 total time=   0.9s
# [CV 5/5] END ....ccp_alpha=3.7888688866176445;, score=-42.672 total time=   0.8s
# [CV 1/5] END ....ccp_alpha=14.733885127559915;, score=-42.996 total time=   1.0s
# [CV 2/5] END ....ccp_alpha=14.733885127559915;, score=-44.444 total time=   1.2s
# [CV 3/5] END ....ccp_alpha=14.733885127559915;, score=-42.842 total time=   1.1s
# [CV 4/5] END ....ccp_alpha=14.733885127559915;, score=-42.975 total time=   1.0s
# [CV 5/5] END ....ccp_alpha=14.733885127559915;, score=-44.206 total time=   1.0s
# [CV 1/5] END ....ccp_alpha=11.796077201994478;, score=-42.704 total time=   1.0s
# [CV 2/5] END ....ccp_alpha=11.796077201994478;, score=-44.182 total time=   0.9s
# [CV 3/5] END ....ccp_alpha=11.796077201994478;, score=-42.842 total time=   0.9s
# [CV 4/5] END ....ccp_alpha=11.796077201994478;, score=-42.701 total time=   0.9s
# [CV 5/5] END ....ccp_alpha=11.796077201994478;, score=-44.062 total time=   1.0s
# [CV 1/5] END ....ccp_alpha=2.0674906804468236;, score=-44.154 total time=   0.9s
# [CV 2/5] END ....ccp_alpha=2.0674906804468236;, score=-44.477 total time=   0.9s
# [CV 3/5] END ....ccp_alpha=2.0674906804468236;, score=-43.307 total time=   1.0s
# [CV 4/5] END ....ccp_alpha=2.0674906804468236;, score=-44.529 total time=   0.9s
# [CV 5/5] END ....ccp_alpha=2.0674906804468236;, score=-43.208 total time=   1.2s
# CPU times: total: 34.1 s
# Wall time: 53.5 s
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=20240210),
#                    param_distributions={'ccp_alpha': [2.0012143674445504,
#                                                       2.012884887551582,
#                                                       2.021341947455082,
#                                                       2.028474759516488,
#                                                       2.033172831959659,
#                                                       2.0624492453038172,
#                                                       2.0674906804468236,
#                                                       2.0678335294814048,
#                                                       2.075282183726335,
#                                                       2.0787436572587783,
#                                                       2.079755945526692,
#                                                       2.0799737513933154,
#                                                       2.0810010042501...
#                                                       2.1144088932793927,
#                                                       2.1238979983187036,
#                                                       2.153369590404287,
#                                                       2.1698438767234562,
#                                                       2.1742199897326735,
#                                                       2.1822607095625592,
#                                                       2.191974950232249,
#                                                       2.223872761772494,
#                                                       2.2315261524994217,
#                                                       2.2315854027471715,
#                                                       2.2413334742816,
#                                                       2.2511149403053707,
#                                                       2.2533029197080245,
#                                                       2.257009058949553,
#                                                       2.2628458232563204,
#                                                       2.274092894129538, ...]},
#                    scoring='neg_root_mean_squared_error', verbose=3)

# %%
cart_rmse = pd.DataFrame(cart_model_cv.cv_results_).loc[
    lambda x: x.param_ccp_alpha == cart_model_cv.best_estimator_.ccp_alpha
].mean_test_score.values[0] * -1
cart_rmse
# Out:
# 42.45774037316889

# %%
cart_model_cv.best_estimator_
# Out:
# DecisionTreeRegressor(ccp_alpha=5.16789792399549, random_state=20240210)

# %% [markdown]
# ## 4. GBM Simple

# %%
gbm = GradientBoostingRegressor(learning_rate=0.1, min_samples_split=20, max_features = 10
                                #, n_estimators = 50
                               )

tune_grid = {"n_estimators": [200, 300], "max_depth": [5, 10]}

gbm_model_cv = GridSearchCV(
    gbm,
    tune_grid,
    cv=5,
    scoring="neg_root_mean_squared_error",
    verbose=10,
    n_jobs=-1
)

# %%
categorical_columns = [col for col in predictors if col.startswith("f_")]
numerical_columns = [col for col in predictors if col not in categorical_columns]

categorical_encoder = OneHotEncoder(handle_unknown="ignore")

preprocessing = ColumnTransformer(
    [
        ("cat", categorical_encoder, categorical_columns),
        ("num", "passthrough", numerical_columns),
    ]
)

gbm_pipe = Pipeline(
    [("preprocess", preprocessing), ("regressor", gbm_model_cv)], verbose=True
)

# %%
# %%time
gbm_pipe.fit(data_train[predictors],data_train.price)
# Out:
# [Pipeline] ........ (step 1 of 2) Processing preprocess, total=   0.0s
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Pipeline] ......... (step 2 of 2) Processing regressor, total=  36.7s
# CPU times: total: 2.91 s
# Wall time: 36.7 s
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['f_property_type',
#                                                    'f_neighbourhood_cleansed']),
#                                                  ('num', 'passthrough',
#                                                   ['n_accommodates',
#                                                    'n_bedrooms', 'n_bathrooms',
#                                                    'n_beds',
#                                                    'n_number_of_reviews',
#                                                    'n_review_scores_rating',
#                                                    'd_host_is_superhost',
#                                                    'd_instant_bookable',
#                                                    'd_windowview', 'd_pool',
#                                                    'd_lu...
#                                                    'd_privatelivingroom',
#                                                    'd_wifi',
#                                                    'd_privateentrance',
#                                                    'd_dryer', 'd_bbq',
#                                                    'd_hairdryer', 'd_breakfast',
#                                                    'd_essentials', ...])])),
#                 ('regressor',
#                  GridSearchCV(cv=5,
#                               estimator=GradientBoostingRegressor(max_features=10,
#                                                                   min_samples_split=20),
#                               n_jobs=-1,
#                               param_grid={'max_depth': [5, 10],
#                                           'n_estimators': [200, 300]},
#                               scoring='neg_root_mean_squared_error',
#                               verbose=10))],
#          verbose=True)

# %%
gbm_model_cv.cv_results_
# Out:
# {'mean_fit_time': array([ 4.6341248 ,  6.50467677,  9.06011729, 10.49140525]),
#  'std_fit_time': array([0.76459697, 1.27673224, 1.88407873, 1.15420965]),
#  'mean_score_time': array([0.03833551, 0.07915449, 0.11681867, 0.07757888]),
#  'std_score_time': array([0.0059842 , 0.02468976, 0.04705056, 0.01685139]),
#  'param_max_depth': masked_array(data=[5, 5, 10, 10],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[200, 300, 200, 300],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 5, 'n_estimators': 200},
#   {'max_depth': 5, 'n_estimators': 300},
#   {'max_depth': 10, 'n_estimators': 200},
#   {'max_depth': 10, 'n_estimators': 300}],
#  'split0_test_score': array([-38.01477533, -38.02447194, -37.43013141, -37.0102246 ]),
#  'split1_test_score': array([-38.19726602, -37.66300984, -37.12609601, -37.16046899]),
#  'split2_test_score': array([-36.41428666, -36.19745786, -35.47830174, -35.6378051 ]),
#  'split3_test_score': array([-38.2157791 , -38.01402475, -37.85843303, -37.72387628]),
#  'split4_test_score': array([-38.00575671, -37.66130946, -36.92828647, -36.46803763]),
#  'mean_test_score': array([-37.76957276, -37.51205477, -36.96424973, -36.80008252]),
#  'std_test_score': array([0.68333435, 0.67642807, 0.80649098, 0.70548928]),
#  'rank_test_score': array([4, 3, 2, 1])}

# %%
gbm_model_cv.best_estimator_
# Out:
# GradientBoostingRegressor(max_depth=10, max_features=10, min_samples_split=20,
#                           n_estimators=300)

# %%
gbm_rmse = gbm_model_cv.best_score_*-1

# %%
gbm_rmse
# Out:
# 36.80008251885095

# %% [markdown]
# #### Getting Predictions for our best model (GBM)

# %%
predictions_holdout = gbm_pipe.predict(data_holdout[predictors])
holdout_prices = data_holdout.price

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(holdout_prices, predictions_holdout, color='#008080', label='Predicted', alpha=0.7, s=15)  # Adjust alpha and s here
plt.plot([min(holdout_prices), max(holdout_prices)], [min(holdout_prices), max(holdout_prices)], color='black', linestyle='--', label='Perfect Prediction')
plt.title('Predicted vs Actual Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Feature Importance and Partial Dependance Plots

# %% [markdown]
# 1. Individual Feature Importance

# %%
y, X = dmatrices("price ~ " + " + ".join(predictors), data_train)

# %%
rf_model.best_estimator_.feature_importances_
# Out:
# array([0.00000000e+00, 1.42014284e-03, 6.18200545e-03, 1.01645314e-03,
#        0.00000000e+00, 0.00000000e+00, 8.18677563e-04, 3.49785842e-05,
#        1.95217114e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.11589832e-05, 0.00000000e+00, 5.63491473e-05, 0.00000000e+00,
#        0.00000000e+00, 9.96039836e-05, 0.00000000e+00, 1.10401404e-04,
#        0.00000000e+00, 3.59535020e-03, 0.00000000e+00, 0.00000000e+00,
#        3.27271755e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.84078925e-04, 8.62448545e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.62225052e-04, 1.75414169e-04, 5.66784330e-04, 9.89389966e-06,
#        0.00000000e+00, 0.00000000e+00, 9.87998799e-05, 7.48590656e-03,
#        2.18213454e-04, 0.00000000e+00, 9.52230473e-06, 0.00000000e+00,
#        0.00000000e+00, 1.33040858e-03, 8.47446472e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.70896393e-03, 0.00000000e+00, 7.77258837e-05, 0.00000000e+00,
#        0.00000000e+00, 2.86450470e-05, 2.80794207e-05, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.16682237e-02,
#        6.01503444e-05, 0.00000000e+00, 2.37499584e-04, 0.00000000e+00,
#        1.30638592e-04, 9.19009943e-04, 8.93183479e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.17076061e-05, 7.67619219e-04,
#        0.00000000e+00, 3.67605951e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.21745917e-02, 0.00000000e+00, 4.30422025e-03,
#        0.00000000e+00, 6.70551070e-05, 0.00000000e+00, 0.00000000e+00,
#        3.77320405e-04, 0.00000000e+00, 2.41571773e-04, 0.00000000e+00,
#        1.47025824e-04, 0.00000000e+00, 1.70212737e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.69666135e-02,
#        8.64506369e-02, 1.15340497e-01, 6.14308605e-02, 5.33752679e-02,
#        5.87209965e-02, 1.24424857e-02, 2.07157461e-02, 1.01490759e-02,
#        9.74968930e-03, 9.74977066e-03, 4.99079204e-05, 8.91446189e-03,
#        1.21367184e-02, 1.25612661e-03, 4.35997983e-03, 3.26335353e-02,
#        1.72756611e-03, 5.70223231e-03, 1.16034313e-02, 6.31734184e-03,
#        2.44108901e-03, 8.33687097e-03, 6.34169371e-04, 9.78218669e-03,
#        1.93442529e-02, 3.63674874e-03, 3.77057134e-03, 3.81678941e-04,
#        9.51615865e-04, 3.38051768e-03, 1.34100317e-02, 2.55075212e-02,
#        5.00571624e-03, 5.84152551e-03, 4.34817649e-03, 8.32307386e-04,
#        5.23083213e-02, 5.83839162e-03, 2.17997658e-02, 7.07362141e-03,
#        1.12194109e-02, 6.27499480e-03, 1.39241825e-02, 1.01149796e-02,
#        1.36564407e-04, 1.07461704e-02, 1.61811347e-02, 4.00277159e-03,
#        9.93630168e-03, 9.31449501e-03, 1.97083391e-02, 6.34550704e-03,
#        4.92533373e-03, 1.09709204e-02])

# %%
pd.DataFrame(
    rf_model.best_estimator_.feature_importances_, 
    X.design_info.column_names)
# Out:
#                                                            0
# Intercept                                           0.000000
# f_property_type[T.Condo]                            0.001420
# f_property_type[T.Apartment]                        0.006182
# f_property_type[T.Loft]                             0.001016
# f_neighbourhood_cleansed[T.Abrigada e Cabanas d...  0.000000
# f_neighbourhood_cleansed[T.Agualva e Mira-Sintra]   0.000000
# f_neighbourhood_cleansed[T.Ajuda]                   0.000819
# f_neighbourhood_cleansed[T.Alcabideche]             0.000035
# f_neighbourhood_cleansed[T.Alcntara]                0.000195
# f_neighbourhood_cleansed[T.Aldeia Galega da Mer...  0.000000
# f_neighbourhood_cleansed[T.Alenquer (Santo Estv...  0.000000
# f_neighbourhood_cleansed[T.Alfragide]               0.000000
# f_neighbourhood_cleansed[T.Algs, Linda-a-Velha ...  0.000071
# f_neighbourhood_cleansed[T.Alguber]                 0.000000
# f_neighbourhood_cleansed[T.Algueiro-Mem Martins]    0.000056
# f_neighbourhood_cleansed[T.Alhandra, So Joo dos...  0.000000
# f_neighbourhood_cleansed[T.Almargem do Bispo, P...  0.000000
# f_neighbourhood_cleansed[T.Alvalade]                0.000100
# f_neighbourhood_cleansed[T.Alverca do Ribatejo ...  0.000000
# f_neighbourhood_cleansed[T.Areeiro]                 0.000110
# f_neighbourhood_cleansed[T.Arranh]                  0.000000
# f_neighbourhood_cleansed[T.Arroios]                 0.003595
# f_neighbourhood_cleansed[T.Arruda dos Vinhos]       0.000000
# f_neighbourhood_cleansed[T.Aveiras de Baixo]        0.000000
# f_neighbourhood_cleansed[T.Avenidas Novas]          0.000327
# f_neighbourhood_cleansed[T.Azambuja]                0.000000
# f_neighbourhood_cleansed[T.Azueira e Sobral da ...  0.000000
# f_neighbourhood_cleansed[T.Barcarena]               0.000000
# f_neighbourhood_cleansed[T.Beato]                   0.000184
# f_neighbourhood_cleansed[T.Belm]                    0.000862
# f_neighbourhood_cleansed[T.Benfica]                 0.000000
# f_neighbourhood_cleansed[T.Bucelas]                 0.000000
# f_neighbourhood_cleansed[T.Cacm e So Marcos]        0.000000
# f_neighbourhood_cleansed[T.Cadaval e Pro Moniz]     0.000000
# f_neighbourhood_cleansed[T.Camarate, Unhos e Ap...  0.000000
# f_neighbourhood_cleansed[T.Campelos e Outeiro d...  0.000000
# f_neighbourhood_cleansed[T.Campo de Ourique]        0.000462
# f_neighbourhood_cleansed[T.Campolide]               0.000175
# f_neighbourhood_cleansed[T.Carcavelos e Parede]     0.000567
# f_neighbourhood_cleansed[T.Carnaxide e Queijas]     0.000010
# f_neighbourhood_cleansed[T.Carnide]                 0.000000
# f_neighbourhood_cleansed[T.Carregado e Cadafais]    0.000000
# f_neighbourhood_cleansed[T.Carvoeira]               0.000099
# f_neighbourhood_cleansed[T.Cascais e Estoril]       0.007486
# f_neighbourhood_cleansed[T.Colares]                 0.000218
# f_neighbourhood_cleansed[T.Dois Portos e Runa]      0.000000
# f_neighbourhood_cleansed[T.Encarnao]                0.000010
# f_neighbourhood_cleansed[T.Encosta do Sol]          0.000000
# f_neighbourhood_cleansed[T.Enxara do Bispo, Gra...  0.000000
# f_neighbourhood_cleansed[T.Ericeira]                0.001330
# f_neighbourhood_cleansed[T.Estrela]                 0.000847
# f_neighbourhood_cleansed[T.Falagueira-Venda Nova]   0.000000
# f_neighbourhood_cleansed[T.Freiria]                 0.000000
# f_neighbourhood_cleansed[T.Igreja Nova e Chelei...  0.000000
# f_neighbourhood_cleansed[T.Lamas e Cercal]          0.000000
# f_neighbourhood_cleansed[T.Loures]                  0.000000
# f_neighbourhood_cleansed[T.Lourinh e Atalaia]       0.001709
# f_neighbourhood_cleansed[T.Lousa]                   0.000000
# f_neighbourhood_cleansed[T.Lumiar]                  0.000078
# f_neighbourhood_cleansed[T.Mafra]                   0.000000
# f_neighbourhood_cleansed[T.Manique do Intendent...  0.000000
# f_neighbourhood_cleansed[T.Marvila]                 0.000029
# f_neighbourhood_cleansed[T.Massam e Monte Abrao]    0.000028
# f_neighbourhood_cleansed[T.Maxial e Monte Redondo]  0.000000
# f_neighbourhood_cleansed[T.Meca]                    0.000000
# f_neighbourhood_cleansed[T.Mina de gua]             0.000000
# f_neighbourhood_cleansed[T.Miragaia e Marteleira]   0.000000
# f_neighbourhood_cleansed[T.Misericrdia]             0.011668
# f_neighbourhood_cleansed[T.Moscavide e Portela]     0.000060
# f_neighbourhood_cleansed[T.Odivelas]                0.000000
# f_neighbourhood_cleansed[T.Oeiras e S.Julio da ...  0.000237
# f_neighbourhood_cleansed[T.Olhalvo]                 0.000000
# f_neighbourhood_cleansed[T.Olivais]                 0.000131
# f_neighbourhood_cleansed[T.Parque das Naes]         0.000919
# f_neighbourhood_cleansed[T.Penha de Frana]          0.000893
# f_neighbourhood_cleansed[T.Peral]                   0.000000
# f_neighbourhood_cleansed[T.Ponte do Rol]            0.000000
# f_neighbourhood_cleansed[T.Pontinha e Fames]        0.000000
# f_neighbourhood_cleansed[T.Porto Salvo]             0.000000
# f_neighbourhood_cleansed[T.Pvoa de Santa Iria e...  0.000000
# f_neighbourhood_cleansed[T.Pvoa de Santo Adrio ...  0.000000
# f_neighbourhood_cleansed[T.Queluz e Belas]          0.000000
# f_neighbourhood_cleansed[T.Ramada e Caneas]         0.000000
# f_neighbourhood_cleansed[T.Reguengo Grande]         0.000000
# f_neighbourhood_cleansed[T.Ribafria e Pereiro d...  0.000000
# f_neighbourhood_cleansed[T.Ribamar]                 0.000000
# f_neighbourhood_cleansed[T.Rio de Mouro]            0.000032
# f_neighbourhood_cleansed[T.S.Maria, S.Miguel, S...  0.000768
# f_neighbourhood_cleansed[T.S.Pedro e Santiago, ...  0.000000
# f_neighbourhood_cleansed[T.Sacavm e Prior Velho]    0.000037
# f_neighbourhood_cleansed[T.Santa Brbara]            0.000000
# f_neighbourhood_cleansed[T.Santa Clara]             0.000000
# f_neighbourhood_cleansed[T.Santa Iria de Azoia,...  0.000000
# f_neighbourhood_cleansed[T.Santa Maria Maior]       0.032175
# f_neighbourhood_cleansed[T.Santiago dos Velhos]     0.000000
# f_neighbourhood_cleansed[T.Santo Antnio]            0.004304
# f_neighbourhood_cleansed[T.Santo Antnio dos Cav...  0.000000
# f_neighbourhood_cleansed[T.Santo Isidoro]           0.000067
# f_neighbourhood_cleansed[T.Santo Quintino]          0.000000
# f_neighbourhood_cleansed[T.Sapataria]               0.000000
# f_neighbourhood_cleansed[T.Silveira]                0.000377
# f_neighbourhood_cleansed[T.So Bartolomeu dos Ga...  0.000000
# f_neighbourhood_cleansed[T.So Domingos de Benfica]  0.000242
# f_neighbourhood_cleansed[T.So Domingos de Rana]     0.000000
# f_neighbourhood_cleansed[T.So Joo das Lampas e ...  0.000147
# f_neighbourhood_cleansed[T.So Pedro da Cadeira]     0.000000
# f_neighbourhood_cleansed[T.So Vicente]              0.001702
# f_neighbourhood_cleansed[T.Sobral de Monte Agrao]   0.000000
# f_neighbourhood_cleansed[T.Turcifal]                0.000000
# f_neighbourhood_cleansed[T.Vale do Paraso]          0.000000
# f_neighbourhood_cleansed[T.Venda do Pinheiro e ...  0.000000
# f_neighbourhood_cleansed[T.Venteira]                0.000000
# f_neighbourhood_cleansed[T.Ventosa]                 0.000000
# f_neighbourhood_cleansed[T.Vialonga]                0.000000
# f_neighbourhood_cleansed[T.Vila Franca de Xira]     0.000000
# f_neighbourhood_cleansed[T.Vila Verde dos Francos]  0.000000
# f_neighbourhood_cleansed[T.Vilar]                   0.000000
# f_neighbourhood_cleansed[T.Vimeiro]                 0.000000
# f_neighbourhood_cleansed[T.guas Livres]             0.000000
# n_accommodates                                      0.066967
# n_bedrooms                                          0.086451
# n_bathrooms                                         0.115340
# n_beds                                              0.061431
# n_number_of_reviews                                 0.053375
# n_review_scores_rating                              0.058721
# d_host_is_superhost                                 0.012442
# d_instant_bookable                                  0.020716
# d_windowview                                        0.010149
# d_pool                                              0.009750
# d_luxuryamenities                                   0.009750
# d_gameconsole                                       0.000050
# d_closet                                            0.008914
# d_paidparking                                       0.012137
# d_gym                                               0.001256
# d_smokingallowed                                    0.004360
# d_airconditioning                                   0.032634
# d_soundsystem                                       0.001728
# d_coffeemaker                                       0.005702
# d_washer                                            0.011603
# d_firstaidkit                                       0.006317
# d_conditioner                                       0.002441
# d_privatelivingroom                                 0.008337
# d_wifi                                              0.000634
# d_privateentrance                                   0.009782
# d_dryer                                             0.019344
# d_bbq                                               0.003637
# d_hairdryer                                         0.003771
# d_breakfast                                         0.000382
# d_essentials                                        0.000952
# d_indoorfireplace                                   0.003381
# d_tv                                                0.013410
# d_elevator                                          0.025508
# d_others                                            0.005006
# d_hangers                                           0.005842
# d_backyard                                          0.004348
# d_hottub                                            0.000832
# d_dishwasher                                        0.052308
# d_petfriendly                                       0.005838
# d_freeparking                                       0.021800
# d_fireextinguisher                                  0.007074
# d_bodysoap                                          0.011219
# d_refrigerator                                      0.006275
# d_shampoo                                           0.013924
# d_workspace                                         0.010115
# d_kitchen                                           0.000137
# d_cabletv                                           0.010746
# d_kidfriendly                                       0.016181
# d_securitycameras                                   0.004003
# d_selfcheckin                                       0.009936
# d_lockbox                                           0.009314
# d_smokedetector                                     0.019708
# d_keypad                                            0.006346
# d_beachaccess                                       0.004925
# d_outdooramenities                                  0.010971

# %%
df_var_imp = pd.DataFrame(
    rf_model.best_estimator_.feature_importances_, 
    X.design_info.column_names)\
    .reset_index()\
    .rename({"index": "variable", 0: "imp"}, axis=1)\
    .sort_values(by=["imp"], ascending=False)\
    .reset_index(drop = True)

df_var_imp['cumulative_imp'] = df_var_imp['imp'].cumsum()

# %%
df_var_imp.style.format({
    'imp': lambda x: f'{x:,.1%}',
    'cumulative_imp': lambda x: f'{x:,.1%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e194">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e194_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_5e194_level0_col1" class="col_heading level0 col1" >imp</th>
#       <th id="T_5e194_level0_col2" class="col_heading level0 col2" >cumulative_imp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e194_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e194_row0_col0" class="data row0 col0" >n_bathrooms</td>
#       <td id="T_5e194_row0_col1" class="data row0 col1" >11.5%</td>
#       <td id="T_5e194_row0_col2" class="data row0 col2" >11.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e194_row1_col0" class="data row1 col0" >n_bedrooms</td>
#       <td id="T_5e194_row1_col1" class="data row1 col1" >8.6%</td>
#       <td id="T_5e194_row1_col2" class="data row1 col2" >20.2%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e194_row2_col0" class="data row2 col0" >n_accommodates</td>
#       <td id="T_5e194_row2_col1" class="data row2 col1" >6.7%</td>
#       <td id="T_5e194_row2_col2" class="data row2 col2" >26.9%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e194_row3_col0" class="data row3 col0" >n_beds</td>
#       <td id="T_5e194_row3_col1" class="data row3 col1" >6.1%</td>
#       <td id="T_5e194_row3_col2" class="data row3 col2" >33.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e194_row4_col0" class="data row4 col0" >n_review_scores_rating</td>
#       <td id="T_5e194_row4_col1" class="data row4 col1" >5.9%</td>
#       <td id="T_5e194_row4_col2" class="data row4 col2" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e194_row5_col0" class="data row5 col0" >n_number_of_reviews</td>
#       <td id="T_5e194_row5_col1" class="data row5 col1" >5.3%</td>
#       <td id="T_5e194_row5_col2" class="data row5 col2" >44.2%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e194_row6_col0" class="data row6 col0" >d_dishwasher</td>
#       <td id="T_5e194_row6_col1" class="data row6 col1" >5.2%</td>
#       <td id="T_5e194_row6_col2" class="data row6 col2" >49.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e194_row7_col0" class="data row7 col0" >d_airconditioning</td>
#       <td id="T_5e194_row7_col1" class="data row7 col1" >3.3%</td>
#       <td id="T_5e194_row7_col2" class="data row7 col2" >52.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e194_row8_col0" class="data row8 col0" >f_neighbourhood_cleansed[T.Santa Maria Maior]</td>
#       <td id="T_5e194_row8_col1" class="data row8 col1" >3.2%</td>
#       <td id="T_5e194_row8_col2" class="data row8 col2" >55.9%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e194_row9_col0" class="data row9 col0" >d_elevator</td>
#       <td id="T_5e194_row9_col1" class="data row9 col1" >2.6%</td>
#       <td id="T_5e194_row9_col2" class="data row9 col2" >58.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5e194_row10_col0" class="data row10 col0" >d_freeparking</td>
#       <td id="T_5e194_row10_col1" class="data row10 col1" >2.2%</td>
#       <td id="T_5e194_row10_col2" class="data row10 col2" >60.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5e194_row11_col0" class="data row11 col0" >d_instant_bookable</td>
#       <td id="T_5e194_row11_col1" class="data row11 col1" >2.1%</td>
#       <td id="T_5e194_row11_col2" class="data row11 col2" >62.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5e194_row12_col0" class="data row12 col0" >d_smokedetector</td>
#       <td id="T_5e194_row12_col1" class="data row12 col1" >2.0%</td>
#       <td id="T_5e194_row12_col2" class="data row12 col2" >64.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5e194_row13_col0" class="data row13 col0" >d_dryer</td>
#       <td id="T_5e194_row13_col1" class="data row13 col1" >1.9%</td>
#       <td id="T_5e194_row13_col2" class="data row13 col2" >66.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5e194_row14_col0" class="data row14 col0" >d_kidfriendly</td>
#       <td id="T_5e194_row14_col1" class="data row14 col1" >1.6%</td>
#       <td id="T_5e194_row14_col2" class="data row14 col2" >68.3%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5e194_row15_col0" class="data row15 col0" >d_shampoo</td>
#       <td id="T_5e194_row15_col1" class="data row15 col1" >1.4%</td>
#       <td id="T_5e194_row15_col2" class="data row15 col2" >69.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5e194_row16_col0" class="data row16 col0" >d_tv</td>
#       <td id="T_5e194_row16_col1" class="data row16 col1" >1.3%</td>
#       <td id="T_5e194_row16_col2" class="data row16 col2" >71.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5e194_row17_col0" class="data row17 col0" >d_host_is_superhost</td>
#       <td id="T_5e194_row17_col1" class="data row17 col1" >1.2%</td>
#       <td id="T_5e194_row17_col2" class="data row17 col2" >72.2%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5e194_row18_col0" class="data row18 col0" >d_paidparking</td>
#       <td id="T_5e194_row18_col1" class="data row18 col1" >1.2%</td>
#       <td id="T_5e194_row18_col2" class="data row18 col2" >73.5%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5e194_row19_col0" class="data row19 col0" >f_neighbourhood_cleansed[T.Misericrdia]</td>
#       <td id="T_5e194_row19_col1" class="data row19 col1" >1.2%</td>
#       <td id="T_5e194_row19_col2" class="data row19 col2" >74.6%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5e194_row20_col0" class="data row20 col0" >d_washer</td>
#       <td id="T_5e194_row20_col1" class="data row20 col1" >1.2%</td>
#       <td id="T_5e194_row20_col2" class="data row20 col2" >75.8%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5e194_row21_col0" class="data row21 col0" >d_bodysoap</td>
#       <td id="T_5e194_row21_col1" class="data row21 col1" >1.1%</td>
#       <td id="T_5e194_row21_col2" class="data row21 col2" >76.9%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5e194_row22_col0" class="data row22 col0" >d_outdooramenities</td>
#       <td id="T_5e194_row22_col1" class="data row22 col1" >1.1%</td>
#       <td id="T_5e194_row22_col2" class="data row22 col2" >78.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5e194_row23_col0" class="data row23 col0" >d_cabletv</td>
#       <td id="T_5e194_row23_col1" class="data row23 col1" >1.1%</td>
#       <td id="T_5e194_row23_col2" class="data row23 col2" >79.1%</td>
#     </tr>
#     <tr>
#       <th id="T_5e194_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5e194_

# %%
# we only care for variables with an importance of more than 1 pct
cutoff = 0.01

# %%
graph1_df = df_var_imp[df_var_imp.imp > cutoff] 
graph1_df = graph1_df.sort_values(by='imp',ascending = False).reset_index(drop = True)
graph1_df = graph1_df.iloc[:10]

# %%
(
    ggplot(graph1_df, aes(x='reorder(variable,imp)', y='imp')) +
    geom_bar(stat='identity', fill='#008080') +
    coord_flip() + theme_minimal() +
    labs(x='',y='Importance', title='Feature Importance - Individual - Top 10') +
    theme(panel_grid_major=element_blank(), panel_grid_minor=element_blank(), 
         plot_title=element_text(size=12), axis_text=element_text(size=10), axis_title=element_text(size=12), 
         figure_size=(10, 6)) + 
    scale_y_continuous(labels=percent_format())
)
# Out:
# <Figure Size: (1000 x 600)>

# %%
categorical_columns = [col for col in predictors if col.startswith("f_")]
numerical_columns = [col for col in predictors if col not in categorical_columns]

# %%
categorical_encoder = OneHotEncoder(handle_unknown="ignore")

preprocessing = ColumnTransformer([
    ("cat", categorical_encoder, categorical_columns),
    ("num", "passthrough", numerical_columns)])

rf_pipeline = Pipeline(
    [("preprocess", preprocessing), 
     ("regressor", rf_model.best_estimator_)] # put best model to pipeline
)

# %%
# %%time
rf_pipeline.fit(data_train[predictors],data_train.price)
# Out:
# CPU times: total: 1.47 s
# Wall time: 2.68 s
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['f_property_type',
#                                                    'f_neighbourhood_cleansed']),
#                                                  ('num', 'passthrough',
#                                                   ['n_accommodates',
#                                                    'n_bedrooms', 'n_bathrooms',
#                                                    'n_beds',
#                                                    'n_number_of_reviews',
#                                                    'n_review_scores_rating',
#                                                    'd_host_is_superhost',
#                                                    'd_instant_bookable',
#                                                    'd_windowview', 'd_pool',
#                                                    'd_lu...
#                                                    'd_paidparking', 'd_gym',
#                                                    'd_smokingallowed',
#                                                    'd_airconditioning',
#                                                    'd_soundsystem',
#                                                    'd_coffeemaker', 'd_washer',
#                                                    'd_firstaidkit',
#                                                    'd_conditioner',
#                                                    'd_privatelivingroom',
#                                                    'd_wifi',
#                                                    'd_privateentrance',
#                                                    'd_dryer', 'd_bbq',
#                                                    'd_hairdryer', 'd_breakfast',
#                                                    'd_essentials', ...])])),
#                 ('regressor',
#                  RandomForestRegressor(max_features=16, min_samples_leaf=5,
#                                        random_state=20240210))])

# %%
# %%time
result = permutation_importance(
    rf_pipeline,
    data_holdout[predictors],
    data_holdout.price,
    n_repeats=10,
    random_state=45,
)
# Out:
# CPU times: total: 54.8 s
# Wall time: 1min 37s

# %%
grouped = [
    "f_property_type",
    "n_bathrooms",
    "n_accommodates",
    "n_beds",
    "f_neighbourhood_cleansed"
]

# %%
df_grouped_var_imp = pd.DataFrame(
        result.importances_mean,
        data_train[predictors].columns)\
    .loc[grouped]\
    .sort_values(by = 0, ascending = False)\
    .reset_index()\
    .rename({'index': 'variable', 0: 'imp'}, axis = 1)
df_grouped_var_imp['cumulative_imp'] = df_grouped_var_imp.imp.cumsum()

# %%
df_grouped_var_imp.style.format({
    'imp': lambda x: f'{x:,.1%}',
    'cumulative_imp': lambda x: f'{x:,.1%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_d00a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d00a0_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_d00a0_level0_col1" class="col_heading level0 col1" >imp</th>
#       <th id="T_d00a0_level0_col2" class="col_heading level0 col2" >cumulative_imp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d00a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d00a0_row0_col0" class="data row0 col0" >n_bathrooms</td>
#       <td id="T_d00a0_row0_col1" class="data row0 col1" >6.7%</td>
#       <td id="T_d00a0_row0_col2" class="data row0 col2" >6.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d00a0_row1_col0" class="data row1 col0" >f_neighbourhood_cleansed</td>
#       <td id="T_d00a0_row1_col1" class="data row1 col1" >3.9%</td>
#       <td id="T_d00a0_row1_col2" class="data row1 col2" >10.6%</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d00a0_row2_col0" class="data row2 col0" >n_accommodates</td>
#       <td id="T_d00a0_row2_col1" class="data row2 col1" >3.5%</td>
#       <td id="T_d00a0_row2_col2" class="data row2 col2" >14.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d00a0_row3_col0" class="data row3 col0" >n_beds</td>
#       <td id="T_d00a0_row3_col1" class="data row3 col1" >1.5%</td>
#       <td id="T_d00a0_row3_col2" class="data row3 col2" >15.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d00a0_row4_col0" class="data row4 col0" >f_property_type</td>
#       <td id="T_d00a0_row4_col1" class="data row4 col1" >0.3%</td>
#       <td id="T_d00a0_row4_col2" class="data row4 col2" >15.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_clean_varimp = pd.DataFrame(
        result.importances_mean,
        data_train[predictors].columns)\
    .sort_values(by = 0, ascending = False)\
    .reset_index()\
    .rename({'index': 'variable', 0: 'imp'}, axis = 1)

df_clean_varimp['cumulative_imp'] = df_var_imp['imp'].cumsum()
df_clean_varimp[df_clean_varimp.cumulative_imp < 0.91]
# Out:
#                     variable       imp  cumulative_imp
# 0                n_bathrooms  0.066769        0.115340
# 1                 n_bedrooms  0.044837        0.201791
# 2   f_neighbourhood_cleansed  0.039200        0.268758
# 3             n_accommodates  0.035430        0.330189
# 4               d_dishwasher  0.032811        0.388910
# 5          d_airconditioning  0.026102        0.442285
# 6              d_freeparking  0.021944        0.494593
# 7     n_review_scores_rating  0.016121        0.527227
# 8         d_instant_bookable  0.015415        0.559401
# 9                     n_beds  0.015340        0.584909
# 10                d_elevator  0.015048        0.606709
# 11             d_kidfriendly  0.010314        0.627424
# 12                   d_dryer  0.009300        0.647133
# 13           d_smokedetector  0.008093        0.666477
# 14       n_number_of_reviews  0.007967        0.682658
# 15                 d_shampoo  0.006092        0.696582
# 16                    d_pool  0.006085        0.709992
# 17       d_host_is_superhost  0.005089        0.722435
# 18                      d_tv  0.004454        0.734571
# 19             d_selfcheckin  0.004128        0.746240
# 20             d_paidparking  0.004100        0.757843
# 21                  d_keypad  0.003964        0.769063
# 22                d_bodysoap  0.003647        0.780033
# 23                  d_washer  0.003213        0.790780
# 24          d_smokingallowed  0.002798        0.800929
# 25        d_outdooramenities  0.002797        0.811044
# 26           f_property_type  0.002649        0.820980
# 27              d_windowview  0.002552        0.830762
# 28         d_luxuryamenities  0.002546        0.840512
# 29         d_securitycameras  0.002043        0.850262
# 30             d_coffeemaker  0.002042        0.859576
# 31               d_workspace  0.002011        0.868491
# 32             d_petfriendly  0.002004        0.876827
# 33            d_refrigerator  0.001969        0.884313
# 34                 d_lockbox  0.001751        0.891387
# 35                 d_cabletv  0.001729        0.897733
# 36        d_fireextinguisher  0.001727        0.904050

# %%
graph2_df = df_clean_varimp.iloc[0:10]
graph2_df = graph2_df.sort_values(by='imp',ascending = False).reset_index(drop = True)
graph2_df
# Out:
#                    variable       imp  cumulative_imp
# 0               n_bathrooms  0.066769        0.115340
# 1                n_bedrooms  0.044837        0.201791
# 2  f_neighbourhood_cleansed  0.039200        0.268758
# 3            n_accommodates  0.035430        0.330189
# 4              d_dishwasher  0.032811        0.388910
# 5         d_airconditioning  0.026102        0.442285
# 6             d_freeparking  0.021944        0.494593
# 7    n_review_scores_rating  0.016121        0.527227
# 8        d_instant_bookable  0.015415        0.559401
# 9                    n_beds  0.015340        0.584909

# %%
(
    ggplot(graph2_df, aes(x='reorder(variable,imp)', y='imp')) +
    geom_bar(stat='identity', fill='#008080') +
    coord_flip() + theme_minimal() +
    labs(x='',y='Importance', title='Feature Importance - Grouped - Top 10') +
    theme(panel_grid_major=element_blank(), panel_grid_minor=element_blank(), 
         plot_title=element_text(size=12), axis_text=element_text(size=10), axis_title=element_text(size=12), 
         figure_size=(10, 6)) + 
    scale_y_continuous(labels=percent_format())
)
# Out:
# <Figure Size: (1000 x 600)>

# %% [markdown]
# ### Partial Dependance Plots

# %%
accomodates_pdp = partial_dependence(
    rf_pipeline, data_holdout[predictors], ["n_accommodates"], kind="average"
)

# %%
graph3_df = pd.DataFrame(
    {'Accommodates': accomodates_pdp['values'][0], 
     'Average Price': accomodates_pdp['average'][0]}
    ).sort_values(by = 'Average Price')

graph3_df
# Out:
#    Accommodates  Average Price
# 0             2     119.117514
# 1             3     120.008572
# 2             4     126.606538
# 3             5     128.451913
# 4             6     131.389469

# %%
(
    ggplot(graph3_df, aes(x='Accommodates', y='Average Price', label='Average Price')) +
    geom_point(size=6, color='#008080') +
    geom_line(color='#008080', alpha=0.5, linetype = 'dashed') + 
    geom_text(size=10, nudge_y=0.6, va='bottom', format_string='{:.1f}') +
    theme_minimal() +
    labs(x='Accomodates', y='', title='Average Price by Number of Accomodates') +
    scale_y_continuous(limits=(115, 135)) +
    theme(
        plot_title=element_text(size=12),
        axis_text=element_text(size=9),
        axis_title=element_text(size=9),
        figure_size=(8, 6)
    )
)
# Out:
# <Figure Size: (800 x 600)>

# %%
roomtype_pdp = partial_dependence(
    rf_pipeline, data_holdout[predictors], ["f_property_type"], kind="average"
)

# %%
graph4_df = pd.DataFrame(
    {'Property Type': roomtype_pdp['values'][0], 
     'Average Price': roomtype_pdp['average'][0]}
    ).sort_values(by = 'Average Price')
graph4_df
# Out:
#   Property Type  Average Price
# 2          Home     124.015270
# 1         Condo     124.803339
# 3          Loft     125.168811
# 0     Apartment     125.770305

# %%
(
    ggplot(graph4_df, aes(x='Property Type', y='Average Price', label='Average Price')) +
    labs(x='Property Type', y='Average Price', title='Average Price by Property Type') + 
    geom_point(size=6, color='#008080') +  
    geom_text(size=10, nudge_y=0.6, va='bottom', format_string='{:.1f}') + 
    theme_minimal() +
    scale_y_continuous(limits=(122, 128)) +
    theme(
        plot_title=element_text(size=12), 
        axis_text=element_text(size=9), 
        axis_title=element_text(size=9),
        figure_size=(8, 6)
    )
)
# Out:
# <Figure Size: (800 x 600)>

# %% [markdown]
# # Comparison
# comparing RMSE of our models

# %%
results = pd.DataFrame({'Model': ['OLS', 'LASSO', 'CART', 'Random Forest', 'GBM'],
              'CV RMSE': [ols_rmse, lasso_rmse, cart_rmse, rf_rmse, gbm_rmse]})
results = results.sort_values(by='CV RMSE', ascending=True).reset_index(drop=True)
results.round(3)
# Out:
#            Model  CV RMSE
# 0            GBM   36.800
# 1            OLS   37.448
# 2          LASSO   38.749
# 3  Random Forest   39.649
# 4           CART   42.458
